# %%
from functions_lib import summary, first_looking, missing_values, duplicate_values, multicolinearity_control, drop_columns, drop_null, shape_control, shape
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
df0 = pd.read_csv("train.csv", low_memory=False)

df = df0.copy()
df.head()
first_looking(df)
duplicate_values(df)
drop_columns(df,[])
drop_null(df, 90)
# Out:
# C:\Users\Toshiba\AppData\Local\Temp\ipykernel_15684\3578334149.py:1: DtypeWarning: Columns (15,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv("train.csv")
# Shape:(2048109, 24)
# ****************************************************************************************************
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2048109 entries, 0 to 2048108
# Data columns (total 24 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   City                  object
#  1   CustomerId            object
#  2   VehicleId             object
#  3   FirstRegistiration    object
#  4   Make                  object
#  5   BodyCode              object
#  6   Serie                 object
#  7   ModelCode             object
#  8   ModelYear             int64
#  9   InvoiceDate           object
#  10  ServiceInvoiceDate    object
#  11  BranchCode            int64
#  12  Milage                int64
#  13  MainGroupDescription  object
#  14  SubGroupDescription   object
#  15  SplitCode             object
#  16  Split_Grubu           object
#  17  ServiceInvoiceLineNo  object
#  18  ItemDescription       object
#  19  ItemNo                object
#  20  ItemType              object
#  21  MainGroupCode         object
#  22  SubGroupCode          object
#  23  IsMalfunction         int64
# dtypes: int64(4), object(20)
# memory usage: 375.0+ MB
# None
# ****************************************************************************************************
# Number of Uniques:
# City                        21
# CustomerId               45185
# VehicleId                52424
# FirstRegistiration        1977
# Make                         4
# BodyCode                    15
# Serie                       11
# ModelCode                  116
# ModelYear                    7
# InvoiceDate               2161
# ServiceInvoiceDate      209095
# BranchCode                  53
# Milage                   77049
# MainGroupDescription       108
# SubGroupDescription        462
# SplitCode                   96
# Split_Grubu                  3
# ServiceInvoiceLineNo       387
# ItemDescription          13285
# ItemNo                   23051
# ItemType                     3
# MainGroupCode               63
# SubGroupCode                81
# IsMalfunction                2
# dtype: int64
# ****************************************************************************************************
# Missing Values:
#                     Missing_Number  Missing_Percent
# FirstRegistiration            7403     3.614554e-03
# CustomerId                     521     2.543810e-04
# Serie                          160     7.812084e-05
# ItemDescription                 27     1.318289e-05
# ItemNo                           1     4.882553e-07
# ****************************************************************************************************
# All Columns:
# - City
# - CustomerId
# - VehicleId
# - FirstRegistiration
# - Make
# - BodyCode
# - Serie
# - ModelCode
# - ModelYear
# - InvoiceDate
# - ServiceInvoiceDate
# - BranchCode
# - Milage
# - MainGroupDescription
# - SubGroupDescription
# - SplitCode
# - Split_Grubu
# - ServiceInvoiceLineNo
# - ItemDescription
# - ItemNo
# - ItemType
# - MainGroupCode
# - SubGroupCode
# - IsMalfunction
# ****************************************************************************************************
# Columns after rename:
# - city
# - customerid
# - vehicleid
# - firstregistiration
# - make
# - bodycode
# - serie
# - modelcode
# - modelyear
# - invoicedate
# - serviceinvoicedate
# - branchcode
# - milage
# - maingroupdescription
# - subgroupdescription
# - splitcode
# - split_grubu
# - serviceinvoicelineno
# - itemdescription
# - itemno
# - itemtype
# - maingroupcode
# - subgroupcode
# - ismalfunction
# ****************************************************************************************************
# Duplicate check...
# There are no duplicates
# ****************************************************************************************************
# Missing value control...
# If there is a missing value above the limit you have given, the relevant columns are dropped and an information is given.
# Last shape after missing value control:(2048109, 24)
# ****************************************************************************************************

# %%
df.head()
# Out:
#        city customerid           vehicleid firstregistiration make bodycode  \
# 0     Muğla   10393975  02i0Y000005Htw6QAC         2018-04-27  BMW      F48
# 1  İstanbul   10817259  02i1i000007CkokAAC         2020-09-24  BMW      F40
# 2  İstanbul   10330911  02i0Y000007Xft3QAC         2018-05-25  BMW      G30
# 3     İzmir    1157429  02i1i000005k7yeAAA         2020-04-10  BMW      F40
# 4     Bursa     912355  02i0Y000007Xkk8QAC         2018-05-29  BMW      G30
#
#           serie modelcode  modelyear          invoicedate  ...  \
# 0        BMW X1      JH11       2018  2021-12-31 00:00:00  ...
# 1  BMW 1 Serisi      7M71       2020  2021-12-29 00:00:00  ...
# 2  BMW 5 Serisi      JA31       2018  2018-10-05 00:00:00  ...
# 3  BMW 1 Serisi      7M71       2020  2020-11-02 00:00:00  ...
# 4  BMW 5 Serisi      JA71       2018  2021-04-01 00:00:00  ...
#
#        subgroupdescription  splitcode  split_grubu serviceinvoicelineno  \
# 0                 Belirsiz         16        other               160000
# 1                 Belirsiz          1        other               140000
# 2                 Belirsiz         85        other               220000
# 3  Sabitlemeli marş motoru         21        other                70000
# 4          Ön cam sileceği         16        other               490000
#
#                           itemdescription       itemno itemtype maingroupcode  \
# 0                             LİFT TAKOZU  51717123311    Parça            01
# 1                          SARF MALZEMESİ  99990601200    Parça      Belirsiz
# 2                                 MALZEME  99990000004    Parça      Belirsiz
# 3  Marş Motorunun Sökülmesi Ve Takılması/      1241520  İşçilik            12
# 4     Her İki Silecek Last.değiştirilmesi      6161541  İşçilik            61
#
#   subgroupcode ismalfunction
# 0     Belirsiz             0
# 1     Belirsiz             0
# 2     Belirsiz             0
# 3           41             0
# 4           61             0
#
# [5 rows x 24 columns]

# %%
df.tail()
# Out:
#              city customerid           vehicleid firstregistiration  make  \
# 2048104    Ankara     360469  02i0Y000005HubdQAC         2018-07-03   BMW
# 2048105  İstanbul    1157429  02i0Y000004hxxOQAQ         2016-01-04   BMW
# 2048106    Ankara    1161346  02i0Y000004hEKWQA2         2017-12-11   BMW
# 2048107  İstanbul    1163007  02i0Y000004hHFHQA2         2018-04-11   BMW
# 2048108    Ankara     360469  02i0Y000004h6DoQAI         2016-12-01  MINI
#
#         bodycode         serie modelcode  modelyear          invoicedate  ...  \
# 2048104      G30  BMW 5 Serisi      JC51       2018  2021-06-25 00:00:00  ...
# 2048105      G11  BMW 7 Serisi      7A01       2015  2016-01-18 00:00:00  ...
# 2048106      G30  BMW 5 Serisi      JA31       2017  2018-05-09 00:00:00  ...
# 2048107      G11  BMW 7 Serisi      7A01       2017  2018-08-17 00:00:00  ...
# 2048108      F55    MINI Hatch      XT31       2016  2018-11-26 00:00:00  ...
#
#         subgroupdescription  splitcode  split_grubu serviceinvoicelineno  \
# 2048104            Belirsiz         52        Hasar               540000
# 2048105            Belirsiz          5        other               130000
# 2048106            Belirsiz          4        other                60000
# 2048107            Belirsiz          1        other               280000
# 2048108            Belirsiz         11        other               310000
#
#                         itemdescription        itemno        itemtype  \
# 2048104                 ALT HAVA KANALI   51137497285           Parça
# 2048105       Bmw & Bmw-Mını Oto Yıkama            75  Harici İşçilik
# 2048106                    ÖN FREN BALA   34106884492           Parça
# 2048107                       BMW ATF 3  83222289720Y           Parça
# 2048108  SİLECEK SİSTEMİ HORTUM ONARIM    61667208073           Parça
#
#         maingroupcode subgroupcode ismalfunction
# 2048104            01     Belirsiz             0
# 2048105      Belirsiz     Belirsiz             0
# 2048106      Belirsiz     Belirsiz             0
# 2048107      Belirsiz     Belirsiz             0
# 2048108      Belirsiz     Belirsiz             0
#
# [5 rows x 24 columns]

# %%
df.sample(5)
# Out:
#              city customerid           vehicleid firstregistiration make  \
# 1278825  İstanbul     620136  02i0Y000004hl01QAA         2016-01-02  BMW
# 495033     Mersin    1017331  02i0Y000004hKpSQAU         2017-07-06  BMW
# 2030776     İzmir   10238081  02i0Y000004fy5tQAA         2017-12-01  BMW
# 1366965  İstanbul     360469  02i0Y000004hE6rQAE         2017-08-15  BMW
# 150939    Kayseri   10687667  02i1i000000SK3yAAG         2019-09-02  BMW
#
#         bodycode         serie modelcode  modelyear          invoicedate  ...  \
# 1278825      F48        BMW X1      HU31       2015  2020-06-03 00:00:00  ...
# 495033       G30  BMW 5 Serisi      JA71       2017  2021-04-16 00:00:00  ...
# 2030776      G30  BMW 5 Serisi      JA31       2017  2021-11-05 00:00:00  ...
# 1366965      G30  BMW 5 Serisi      JA31       2017  2019-10-14 00:00:00  ...
# 150939       F48        BMW X1      31AC       2019  2020-10-27 00:00:00  ...
#
#         subgroupdescription  splitcode  split_grubu serviceinvoicelineno  \
# 1278825            Belirsiz         16        other               210000
# 495033             Belirsiz         12        other                50000
# 2030776            Belirsiz          1        other               230000
# 1366965          Denetimler         11        other                20000
# 150939             Belirsiz          1        other               350000
#
#                               itemdescription       itemno        itemtype  \
# 1278825                         HAVA FİLTRESİ  13718513944           Parça
# 495033   Verisi Olmayan İşçilik Süresi/ön Aks      3199000         İşçilik
# 2030776         BMW ORIJINAL CAM SUYU KATKISI  83125A1A174           Parça
# 1366965             Servisin Standart Kapsamı      0000105         İşçilik
# 150939                       Mekanik İşlemler           20  Harici İşçilik
#
#         maingroupcode subgroupcode ismalfunction
# 1278825      Belirsiz     Belirsiz             0
# 495033             31           99             0
# 2030776      Belirsiz     Belirsiz             0
# 1366965            00           00             0
# 150939       Belirsiz     Belirsiz             0
#
# [5 rows x 24 columns]

# %%
df.ismalfunction.value_counts()
# Out:
# 0    2034757
# 1      13352
# Name: ismalfunction, dtype: int64

# %%
df.ismalfunction.value_counts(normalize=True) * 100
# Out:
# 0    99.348082
# 1     0.651918
# Name: ismalfunction, dtype: float64
