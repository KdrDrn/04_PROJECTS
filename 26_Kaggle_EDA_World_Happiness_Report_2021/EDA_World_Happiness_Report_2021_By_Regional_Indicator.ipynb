# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # AN EDA STUDY ON WORLD HAPPINESS REPORT 2021 DATASET

# %% [markdown]
# ## What is World Happiness Report?
#
# The World Happiness Report is a publication of the United Nations Sustainable Development Solutions Network. It contains articles and rankings of national happiness, based on respondent ratings of their own lives, which the report also correlates with various (quality of) life factors. As of March 2021, Finland had been ranked the happiest country in the world four times in a row.
#
# The report primarily uses data from the Gallup World Poll. Each annual report is available to the public to download on the World Happiness Report website.
#
# https://en.wikipedia.org/wiki/World_Happiness_Report

# %% [markdown]
# ## What is Exploratory Data Analysis?
#
# Exploratory Data Analysis (EDA), also known as Data Exploration, is a step in the Data Analysis Process, where a number of techniques are used to better understand the dataset being used.
#
# ‘Understanding the dataset’ can refer to a number of things including but not limited to…
#
# - Extracting important variables and leaving behind useless variables
# - Identifying outliers, missing values, or human error
# - Understanding the relationship(s), or lack of, between variables
# - Ultimately, maximizing your insights of a dataset and minimizing potential error that may occur later in the process
#
# By conducting EDA, you can turn an almost useable dataset into a completely useable dataset.
#
# Exploratory Data Analysis does two main things:
#
# - It helps clean up a dataset.
# - It gives you a better understanding of the variables and the relationships between them.
#
# There are main components of exploring data:
#
# - Understanding your variables
# - Cleaning your dataset
# - Analyzing relationships between variables with Data Visualization

# %% [markdown]
# ### Let's begin with importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### It is time to load and read the dataset to get an overview

# %%
# CODE HERE to load and read "world-happiness-report-2021.csv"

# %%
df = pd.read_csv("world-happiness-report-2021.csv")

# %%
# CODE HERE to get the below output

# %%
df.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904          7.78
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
#
# ...

# %%
# CODE HERE to see the columns

# %%
# df.keys()
df.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %% [markdown]
# From the above data frame, make a new data frame named "df_2021", which should include the following columns / variables:
#
# ['Country name', 'Regional indicator', 'Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']

# %%
# CODE HERE

# %%
df_2021= df[['Country name','Regional indicator','Ladder score','Logged GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']].copy()

# %%
# CODE HERE to get first 5 rows

# %%
df_2021.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
# 2  Switzerland     Western Europe         7.571                 11.117
# 3      Iceland     Western Europe         7.554                 10.878
# 4  Netherlands     Western Europe         7.464                 10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption
# 0      -0.098                      0.186
# ...

# %%
# CODE HERE to get last 5 rows

# %%
df_2021.tail()
# Out:
#     Country name  Regional indicator  Ladder score  Logged GDP per capita  \
# 144      Lesotho  Sub-Saharan Africa         3.512                  7.926
# 145     Botswana  Sub-Saharan Africa         3.467                  9.782
# 146       Rwanda  Sub-Saharan Africa         3.415                  7.676
# 147     Zimbabwe  Sub-Saharan Africa         3.145                  7.943
# 148  Afghanistan          South Asia         2.523                  7.695
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 144           0.787                   48.700                         0.715
# 145           0.784                   59.269                         0.824
# 146           0.552                   61.400                         0.897
# 147           0.750                   56.201                         0.677
# 148           0.463                   52.493                         0.382
#
#      Generosity  Perceptions of corruption
# ...

# %%
# CODE HERE to get 5 random rows

# %%
df_2021.sample(5)
# Out:
#            Country name            Regional indicator  Ladder score  \
# 111               Gabon            Sub-Saharan Africa         4.852
# 98                Benin            Sub-Saharan Africa         5.045
# 146              Rwanda            Sub-Saharan Africa         3.415
# 72   Dominican Republic   Latin America and Caribbean         5.545
# 105             Morocco  Middle East and North Africa         4.918
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 111                  9.603           0.776                   59.962
# 98                   8.087           0.489                   54.713
# 146                  7.676           0.552                   61.400
# 72                   9.802           0.853                   66.102
# 105                  8.903           0.560                   66.208
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 111                         0.731      -0.200                      0.840
# ...

# %%
# CODE HERE to get shape of the dataframe

# %%
df_2021.shape
# Out:
# (149, 9)

# %%
# CODE HERE to get len of the dataframe

# %%
len(df_2021)
# Out:
# 149

# %%
# CODE HERE to get size of the dataframe

# %%
df_2021.size
# Out:
# 1341

# %%
# CODE HERE to get below output

# %%
df_2021.index
# Out:
# RangeIndex(start=0, stop=149, step=1)

# %%
# CODE HERE to get below output

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  149 non-null    object
#  1   Regional indicator            149 non-null    object
#  2   Ladder score                  149 non-null    float64
#  3   Logged GDP per capita         149 non-null    float64
#  4   Social support                149 non-null    float64
#  5   Healthy life expectancy       149 non-null    float64
#  6   Freedom to make life choices  149 non-null    float64
#  7   Generosity                    149 non-null    float64
#  8   Perceptions of corruption     149 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 10.6+ KB

# %%
# CODE HERE to get below output

# %%
df_2021.describe()
# Out:
#        Ladder score  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.532839               9.432208        0.814745
# std        1.073924               1.158601        0.114889
# min        2.523000               6.635000        0.463000
# 25%        4.852000               8.541000        0.750000
# 50%        5.534000               9.569000        0.832000
# 75%        6.255000              10.421000        0.905000
# max        7.842000              11.647000        0.983000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               149.000000                    149.000000  149.000000
# mean                 64.992799                      0.791597   -0.015134
# std                   6.762043                      0.113332    0.150657
# min                  48.478000                      0.382000   -0.288000
# ...

# %%
# CODE HERE to get below output

# %%
df_2021.describe(include = object)
# Out:
#        Country name  Regional indicator
# count           149                 149
# unique          149                  10
# top         Finland  Sub-Saharan Africa
# freq              1                  36

# %%
# CODE HERE to get below output

# %%
df_2021.describe(include = 'all')
# Out:
#        Country name  Regional indicator  Ladder score  Logged GDP per capita  \
# count           149                 149    149.000000             149.000000
# unique          149                  10           NaN                    NaN
# top         Finland  Sub-Saharan Africa           NaN                    NaN
# freq              1                  36           NaN                    NaN
# mean            NaN                 NaN      5.532839               9.432208
# std             NaN                 NaN      1.073924               1.158601
# min             NaN                 NaN      2.523000               6.635000
# 25%             NaN                 NaN      4.852000               8.541000
# 50%             NaN                 NaN      5.534000               9.569000
# 75%             NaN                 NaN      6.255000              10.421000
# max             NaN                 NaN      7.842000              11.647000
#
# ...

# %%
# CODE HERE to get below output

# %%
dtypes = pd.DataFrame(df_2021.dtypes, columns = ['dtypes'])
dtypes
# Out:
#                                dtypes
# Country name                   object
# Regional indicator             object
# Ladder score                  float64
# Logged GDP per capita         float64
# Social support                float64
# Healthy life expectancy       float64
# Freedom to make life choices  float64
# Generosity                    float64
# Perceptions of corruption     float64

# %%
# CODE HERE to get below output

# %%
notnull = pd.DataFrame(df_2021.notnull().sum(), columns = ['notnull'])
notnull
# Out:
#                               notnull
# Country name                      149
# Regional indicator                149
# Ladder score                      149
# Logged GDP per capita             149
# Social support                    149
# Healthy life expectancy           149
# Freedom to make life choices      149
# Generosity                        149
# Perceptions of corruption         149

# %%
# CODE HERE to get below output

# %%
isnull = pd.DataFrame(df_2021.isnull().sum(), columns = ['isnull'])
isnull
# Out:
#                               isnull
# Country name                       0
# Regional indicator                 0
# Ladder score                       0
# Logged GDP per capita              0
# Social support                     0
# Healthy life expectancy            0
# Freedom to make life choices       0
# Generosity                         0
# Perceptions of corruption          0

# %%
# CODE HERE

# %%
nunique = pd.DataFrame([df_2021[i].nunique() for i in df_2021.columns], index = df_2021.columns, columns = ['nunique'])
nunique
# Out:
#                               nunique
# Country name                      149
# Regional indicator                 10
# Ladder score                      147
# Logged GDP per capita             148
# Social support                    119
# Healthy life expectancy           135
# Freedom to make life choices      126
# Generosity                        130
# Perceptions of corruption         130

# %%
# CODE HERE

# %%
pd.concat([dtypes, notnull, isnull, nunique], axis = 1).reset_index().rename({'index':'Columns'},axis = 1)
# Out:
#                         Columns   dtypes  notnull  isnull  nunique
# 0                  Country name   object      149       0      149
# 1            Regional indicator   object      149       0       10
# 2                  Ladder score  float64      149       0      147
# 3         Logged GDP per capita  float64      149       0      148
# 4                Social support  float64      149       0      119
# 5       Healthy life expectancy  float64      149       0      135
# 6  Freedom to make life choices  float64      149       0      126
# 7                    Generosity  float64      149       0      130
# 8     Perceptions of corruption  float64      149       0      130

# %%
# CODE HERE to get duplicated values

# %%
df_2021.duplicated().value_counts()
# Out:
# False    149
# dtype: int64

# %%
df1_2021["Regional indicator"].value_counts()
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: Regional indicator, dtype: int64

# %%
plt.figure(figsize = (12, 8))
sns.countplot(data = df1_2021, x = "Regional indicator", order = df1_2021["Regional indicator"].value_counts().index)

for index, value in enumerate(df1_2021["Regional indicator"].value_counts().values):
    plt.text(index, value, str(value), ha = "center", va = "bottom")
    
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(df1_2021.corr(), annot=True);

# %%
plt.figure(figsize = (20, 20))
sns.pairplot(df1_2021, hue = "Regional indicator", corner = True, diag_kind = "kde");

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = df1_2021["Ladder score"], y = df1_2021["Logged GDP per capita"], hue = df1_2021["Regional indicator"]);

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = df1_2021["Ladder score"], y = df1_2021["Social support"], hue = df1_2021["Regional indicator"]);

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = df1_2021["Ladder score"], y = df1_2021["Healthy life expectancy"], hue = df1_2021["Regional indicator"]);

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = df1_2021["Ladder score"], y = df1_2021["Freedom to make life choices"], hue = df1_2021["Regional indicator"]);

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = df1_2021["Ladder score"], y = df1_2021["Generosity"], hue = df1_2021["Regional indicator"]);

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = df1_2021["Ladder score"], y = df1_2021["Perceptions of corruption"], hue = df1_2021["Regional indicator"]);

# %% [markdown]
# ### Ladder score according to Regional indicator

# %%
Ladder_score_by_Regional_indicator = df1_2021.groupby("Regional indicator").mean()["Ladder score"].sort_values(ascending = False).round(2)
Ladder_score_by_Regional_indicator
# Out:
# Regional indicator
# North America and ANZ                 7.13
# Western Europe                        6.91
# Central and Eastern Europe            5.98
# Latin America and Caribbean           5.91
# East Asia                             5.81
# Commonwealth of Independent States    5.47
# Southeast Asia                        5.41
# Middle East and North Africa          5.22
# Sub-Saharan Africa                    4.49
# South Asia                            4.44
# Name: Ladder score, dtype: float64

# %%
plt.figure(figsize = (12, 8))
ax = sns.barplot(data = df1_2021, x = Ladder_score_by_Regional_indicator.index, 
            y = Ladder_score_by_Regional_indicator.values)

ax.set(ylabel = "Ladder Score")

for index, value in enumerate(Ladder_score_by_Regional_indicator.values):
    plt.text(index, value, str(value), ha = "center", va = "bottom")
    
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data = df1_2021, x = Ladder_score_by_Regional_indicator.values);

# %% [markdown]
# ### Logged GDP per capita according to Regional indicator

# %%
Logged_GDP_per_capita_by_Regional_indicator = df1_2021.groupby("Regional indicator").mean()["Logged GDP per capita"].sort_values(ascending = False).round(2)
Logged_GDP_per_capita_by_Regional_indicator
# Out:
# Regional indicator
# Western Europe                        10.82
# North America and ANZ                 10.81
# East Asia                             10.37
# Central and Eastern Europe            10.11
# Middle East and North Africa           9.67
# Southeast Asia                         9.42
# Commonwealth of Independent States     9.40
# Latin America and Caribbean            9.37
# South Asia                             8.68
# Sub-Saharan Africa                     8.08
# Name: Logged GDP per capita, dtype: float64

# %%
plt.figure(figsize = (12, 8))
sns.barplot(data = df1_2021, x = Logged_GDP_per_capita_by_Regional_indicator.index, 
            y = Logged_GDP_per_capita_by_Regional_indicator.values)

ax.set(ylabel = "Logged GDP per capita")

for index, value in enumerate(Logged_GDP_per_capita_by_Regional_indicator.values):
    plt.text(index, value, str(value), ha = "center", va = "bottom")
    
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data = df1_2021, x = Logged_GDP_per_capita_by_Regional_indicator.values);

# %% [markdown]
# ### Social support according to Regional indicator

# %%
Social_support_by_Regional_indicator = df1_2021.groupby("Regional indicator").mean()["Social support"].sort_values(ascending = False).round(2)
Social_support_by_Regional_indicator
# Out:
# Regional indicator
# North America and ANZ                 0.93
# Western Europe                        0.91
# Central and Eastern Europe            0.89
# Commonwealth of Independent States    0.87
# East Asia                             0.86
# Latin America and Caribbean           0.84
# Southeast Asia                        0.82
# Middle East and North Africa          0.80
# South Asia                            0.70
# Sub-Saharan Africa                    0.70
# Name: Social support, dtype: float64

# %%
plt.figure(figsize = (12, 8))
sns.barplot(data = df1_2021, x = Social_support_by_Regional_indicator.index, 
            y = Social_support_by_Regional_indicator.values)

ax.set(ylabel = "Social support")

for index, value in enumerate(Social_support_by_Regional_indicator.values):
    plt.text(index, value, str(value), ha = "center", va = "bottom")
    
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data = df1_2021, x = Social_support_by_Regional_indicator.values);

# %% [markdown]
# ### Healthy life expectancy according to Regional indicator

# %%
Healthy_life_expectancy_by_Regional_indicator = df1_2021.groupby("Regional indicator").mean()["Healthy life expectancy"].sort_values(ascending = False).round(2)
Healthy_life_expectancy_by_Regional_indicator
# Out:
# Regional indicator
# Western Europe                        73.03
# North America and ANZ                 72.32
# East Asia                             71.25
# Central and Eastern Europe            68.34
# Latin America and Caribbean           67.08
# Middle East and North Africa          65.61
# Commonwealth of Independent States    65.01
# Southeast Asia                        64.89
# South Asia                            62.68
# Sub-Saharan Africa                    55.89
# Name: Healthy life expectancy, dtype: float64

# %%
plt.figure(figsize = (12, 8))
sns.barplot(data = df1_2021, x = Healthy_life_expectancy_by_Regional_indicator.index, 
            y = Healthy_life_expectancy_by_Regional_indicator.values)

ax.set(ylabel = "Healthy life expectancy")

for index, value in enumerate(Healthy_life_expectancy_by_Regional_indicator.values):
    plt.text(index, value, str(value), ha = "center", va = "bottom")
    
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data = df1_2021, x = Healthy_life_expectancy_by_Regional_indicator.values);

# %% [markdown]
# ### Freedom to make life choices according to Regional indicator

# %%
Freedom_to_make_life_choices_by_Regional_indicator = df1_2021.groupby("Regional indicator").mean()["Freedom to make life choices"].sort_values(ascending = False).round(2)
Freedom_to_make_life_choices_by_Regional_indicator
# Out:
# Regional indicator
# Southeast Asia                        0.91
# North America and ANZ                 0.90
# Western Europe                        0.86
# Latin America and Caribbean           0.83
# Commonwealth of Independent States    0.82
# Central and Eastern Europe            0.80
# South Asia                            0.76
# East Asia                             0.76
# Sub-Saharan Africa                    0.72
# Middle East and North Africa          0.72
# Name: Freedom to make life choices, dtype: float64

# %%
plt.figure(figsize = (12, 8))
sns.barplot(data = df1_2021, x = Freedom_to_make_life_choices_by_Regional_indicator.index, 
            y = Freedom_to_make_life_choices_by_Regional_indicator.values)

ax.set(ylabel = "Freedom to make life choices")

for index, value in enumerate(Freedom_to_make_life_choices_by_Regional_indicator.values):
    plt.text(index, value, str(value), ha = "center", va = "bottom")
    
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data = df1_2021, x = Freedom_to_make_life_choices_by_Regional_indicator.values);

# %% [markdown]
# ### Generosity according to Regional indicator

# %%
Generosity_by_Regional_indicator = df1_2021.groupby("Regional indicator").mean()["Generosity"].sort_values(ascending = False).round(2)
Generosity_by_Regional_indicator
# Out:
# Regional indicator
# Southeast Asia                        0.16
# North America and ANZ                 0.12
# South Asia                            0.04
# Sub-Saharan Africa                    0.01
# Western Europe                       -0.00
# Commonwealth of Independent States   -0.04
# East Asia                            -0.06
# Latin America and Caribbean          -0.07
# Central and Eastern Europe           -0.08
# Middle East and North Africa         -0.08
# Name: Generosity, dtype: float64

# %%
plt.figure(figsize = (12, 8))
sns.barplot(data = df1_2021, x = Generosity_by_Regional_indicator.index, 
            y = Generosity_by_Regional_indicator.values)

ax.set(ylabel = "Generosity")

for index, value in enumerate(Generosity_by_Regional_indicator.values):
    plt.text(index, value, str(value), ha = "center", va = "bottom")
    
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data = df1_2021, x = Generosity_by_Regional_indicator.values);

# %% [markdown]
# ### Perceptions of corruption according to Regional indicator

# %%
Perceptions_of_corruption_by_Regional_indicator = df1_2021.groupby("Regional indicator").mean()["Perceptions of corruption"].sort_values(ascending = False).round(2)
Perceptions_of_corruption_by_Regional_indicator
# Out:
# Regional indicator
# Central and Eastern Europe            0.85
# South Asia                            0.80
# Latin America and Caribbean           0.79
# Sub-Saharan Africa                    0.77
# Middle East and North Africa          0.76
# Commonwealth of Independent States    0.73
# Southeast Asia                        0.71
# East Asia                             0.68
# Western Europe                        0.52
# North America and ANZ                 0.45
# Name: Perceptions of corruption, dtype: float64

# %%
plt.figure(figsize = (12, 8))
sns.barplot(data = df1_2021, x = Perceptions_of_corruption_by_Regional_indicator.index, 
            y = Perceptions_of_corruption_by_Regional_indicator.values)

ax.set(ylabel = "Perceptions of corruption")

for index, value in enumerate(Perceptions_of_corruption_by_Regional_indicator.values):
    plt.text(index, value, str(value), ha = "center", va = "bottom")
    
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(data = df1_2021, x = Perceptions_of_corruption_by_Regional_indicator.values);

# %%
df_2021.shape
# Out:
# (149, 9)

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
