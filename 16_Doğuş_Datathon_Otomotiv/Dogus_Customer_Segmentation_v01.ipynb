# %%
#!pip install pyforest

# 1-Import Libraies
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.formula.api as smf
import missingno as msno 

from sklearn.compose import make_column_transformer

#Scaling
from sklearn.preprocessing import scale 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler


#Importing plotly and cufflinks in offline mode
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

#Ignore Warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

#Figure&Display options
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('max_colwidth',200)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

#!pip install termcolor
import colorama
from colorama import Fore, Style  # maakes strings colored
from termcolor import colored

import ipywidgets
from ipywidgets import interact
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
## Useful Functions

###############################################################################

def missing(df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values

def missing_values(df):
    return missing(df)[missing(df)['Missing_Number']>0]

###############################################################################

def first_looking(df):
    print(colored("Shape:", attrs=['bold']), df.shape,'\n',
          f"There is ", df.shape[0], " observation and ", df.shape[1], " columns in the dataset.", '\n',
          colored('-'*79, 'red', attrs=['bold']),
          colored("\nInfo:\n", attrs=['bold']), sep='')
    print(df.info(), '\n', 
          colored('-'*79, 'red', attrs=['bold']), sep='')
    print(colored("Number of Uniques:\n", attrs=['bold']), df.nunique(),'\n',
          colored('-'*79, 'red', attrs=['bold']), sep='')
    print(colored("Missing Values:\n", attrs=['bold']), missing_values(df),'\n', 
          colored('-'*79, 'red', attrs=['bold']), sep='')
    print(colored("All Columns:", attrs=['bold']), list(df.columns),'\n', 
          colored('-'*79, 'red', attrs=['bold']), sep='')

    df.columns= df.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')

    print(colored("Columns after rename:", attrs=['bold']), list(df.columns),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')

def duplicate_values(df):
    duplicate_values = df.duplicated(subset=None, keep='first').sum()
    if duplicate_values > 0:
        df.drop_duplicates(keep='first', inplace=True)
        print(duplicate_values, colored("duplicates were dropped", attrs=['bold']),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')
    else:
        print(colored("No duplicates", attrs=['bold']),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')
        
def drop_columns(df, drop_columns):
    if drop_columns !=[]:
        df.drop(drop_columns, axis=1, inplace=True)
        print(drop_columns, 'were dropped')
    else:
        print(colored('We will now check the missing values and if necessary drop some columns!!!', attrs=['bold']),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')
        
def drop_null(df, limit):
    print('Shape:', df.shape)
    for i in df.isnull().sum().index:
        if (df.isnull().sum()[i]/df.shape[0]*100)>limit:
            print(df.isnull().sum()[i], 'percent of', i ,'null and were dropped')
            df.drop(i, axis=1, inplace=True)
            print('new shape:', df.shape)
        else:
            print(df.isnull().sum()[i], '%, percentage of missing values of', i ,'less than limit', limit, '%, so we will keep it.')
    print('New shape after missing value control:', df.shape)

###############################################################################

# %% [markdown]
#     FINAL_CUSTOMER_DATATHON.csv
#     Index(['unnamed:_0', 'base_customer_id', 'customer_id', 'gender', 'gender_id',
#            'marital_status', 'marital_status_id', 'birth_date',
#            'fk_address_communication_city', 'occupation'], dtype='object')
#
#     FINAL_CUSTOMER_RELATED_TABLE_FOR_DATATHON.csv
#     Index(['unnamed:_0', 'base_customer_id', 'vehicle_id', 'start_date',
#            'end_date', 'fk_relation_status_id', 'fk_relation_status_explanation'], dtype='object')
#
#     FINAL_SALES_FILE_DATATHON.csv
#     Index(['unnamed:_0', 'customer_id', 'salesfile_id', 'sf_create_date', 'status',
#            'req_brand_code', 'req_topmodel_code'], dtype='object')
#
#     FINAL_SIFIR_ARAC_ALANLAR_DATATHON.csv
#     Index(['unnamed:_0', 'vehicle_id', 'traffic_date', 'brand_code',
#            'basemodel_code', 'topmodel_code', 'motor_gas_type', 'gear_box_type'], dtype='object')
#
#     FINAL_VEHICLE_TABLE_DATATHON.csv
#     Index(['unnamed:_0', 'vehicle_id', 'customer_id', 'create_date'], dtype='object')
#
#     MASK_SERVIS_BAKIM_DATATHON_FINAL.csv
#     Index(['unnamed:_0', 'create_date', 'is_maintenance', 'vehicle_id',
#            'total_amount_tl'], dtype='object')
#
#     sample_submission.csv
#     Index(['id', 'expected'], dtype='object')

# %%
dataset_path1 = "D_FINAL_CUSTOMER_DATATHON.csv"
df1_ = pd.read_csv(dataset_path1)
dataset_path2 = "D_FINAL_CUSTOMER_RELATED_TABLE_FOR_DATATHON.csv"
df2_ = pd.read_csv(dataset_path2)
dataset_path3 = "D_FINAL_SALES_FILE_DATATHON.csv"
df3_ = pd.read_csv(dataset_path3)
dataset_path4 = "D_FINAL_SIFIR_ARAC_ALANLAR_DATATHON.csv"
df4_ = pd.read_csv(dataset_path4)
dataset_path5 = "D_FINAL_VEHICLE_TABLE_DATATHON.csv"
df5_ = pd.read_csv(dataset_path5)
dataset_path6 = "D_MASK_SERVIS_BAKIM_DATATHON_FINAL.csv"
df6_ = pd.read_csv(dataset_path6)
dataset_path7 = "D_sample_submission.csv"
df7_ = pd.read_csv(dataset_path7)

# %%
# # lets check the Summary Statistics for each of the Crops

# @interact
# def summary(df_list):
#     first_looking(df)
#     duplicate_values(df)
#     drop_columns(df,[])
#     drop_null(df, 90)

# %%
# 2-Load|Read Data
dataset_path = "D_FINAL_CUSTOMER_DATATHON.csv"
df0 = pd.read_csv(dataset_path)
df = df0.copy() 
first_looking(df)
duplicate_values(df)
drop_columns(df,[])
drop_null(df, 90)
# df.head()
# df.tail()
# df.sample(5)
# df.describe().T
# df.describe(include=object).T
# Out:
# Shape:(849919, 10)
# There is 849919 observation and 10 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 849919 entries, 0 to 849918
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     849919 non-null  int64
#  1   BASE_CUSTOMER_ID               849919 non-null  int64
#  2   CUSTOMER_ID                    849919 non-null  int64
#  3   GENDER                         849916 non-null  object
#  4   GENDER_ID                      849919 non-null  int64
#  5   MARITAL_STATUS                 620802 non-null  object
#  6   MARITAL_STATUS_ID              849919 non-null  int64
#  7   BIRTH_DATE                     645447 non-null  float64
#  8   FK_ADDRESS_COMMUNICATION_CITY  730341 non-null  object
#  9   OCCUPATION                     381052 non-null  object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 64.8+ MB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# Unnamed: 0                       849919
# BASE_CUSTOMER_ID                 196564
# CUSTOMER_ID                      849919
# GENDER                                2
# GENDER_ID                             3
# MARITAL_STATUS                        2
# MARITAL_STATUS_ID                     3
# BIRTH_DATE                          107
# FK_ADDRESS_COMMUNICATION_CITY       142
# OCCUPATION                           63
# dtype: int64
# -------------------------------------------------------------------------------
# Missing Values:
#                                Missing_Number  Missing_Percent
# OCCUPATION                             468867            0.552
# MARITAL_STATUS                         229117            0.270
# BIRTH_DATE                             204472            0.241
# FK_ADDRESS_COMMUNICATION_CITY          119578            0.141
# GENDER                                      3            0.000
# -------------------------------------------------------------------------------
# All Columns:['Unnamed: 0', 'BASE_CUSTOMER_ID', 'CUSTOMER_ID', 'GENDER', 'GENDER_ID', 'MARITAL_STATUS', 'MARITAL_STATUS_ID', 'BIRTH_DATE', 'FK_ADDRESS_COMMUNICATION_CITY', 'OCCUPATION']
# -------------------------------------------------------------------------------
# Columns after rename:['unnamed:_0', 'base_customer_id', 'customer_id', 'gender', 'gender_id', 'marital_status', 'marital_status_id', 'birth_date', 'fk_address_communication_city', 'occupation']
# -------------------------------------------------------------------------------
# No duplicates
# -------------------------------------------------------------------------------
# We will now check the missing values and if necessary drop some columns!!!
# -------------------------------------------------------------------------------
# Shape: (849919, 10)
# 0 %, percentage of missing values of unnamed:_0 less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of base_customer_id less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of customer_id less than limit 90 %, so we will keep it.
# 3 %, percentage of missing values of gender less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of gender_id less than limit 90 %, so we will keep it.
# 229117 %, percentage of missing values of marital_status less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of marital_status_id less than limit 90 %, so we will keep it.
# 204472 %, percentage of missing values of birth_date less than limit 90 %, so we will keep it.
# 119578 %, percentage of missing values of fk_address_communication_city less than limit 90 %, so we will keep it.
# 468867 %, percentage of missing values of occupation less than limit 90 %, so we will keep it.
# New shape after missing value control: (849919, 10)

# %%
# 2-Load|Read Data
dataset_path = "D_FINAL_CUSTOMER_RELATED_TABLE_FOR_DATATHON.csv"
df0 = pd.read_csv(dataset_path)
df = df0.copy() 
first_looking(df)
duplicate_values(df)
drop_columns(df,[])
drop_null(df, 90)
# df.head()
# df.tail()
# df.sample(5)
# df.describe().T
# df.describe(include=object).T
# Out:
# Shape:(374879, 7)
# There is 374879 observation and 7 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374879 entries, 0 to 374878
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      374879 non-null  int64
#  1   BASE_CUSTOMER_ID                374879 non-null  int64
#  2   VEHICLE_ID                      374879 non-null  int64
#  3   START_DATE                      374879 non-null  object
#  4   END_DATE                        159757 non-null  object
#  5   FK_RELATION_STATUS_ID           374879 non-null  int64
#  6   FK_RELATION_STATUS_EXPLANATION  374879 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 20.0+ MB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# Unnamed: 0                        374879
# BASE_CUSTOMER_ID                  196538
# VEHICLE_ID                        345092
# START_DATE                          8132
# END_DATE                            6164
# FK_RELATION_STATUS_ID                  2
# FK_RELATION_STATUS_EXPLANATION         2
# dtype: int64
# -------------------------------------------------------------------------------
# Missing Values:
#           Missing_Number  Missing_Percent
# END_DATE          215122            0.574
# -------------------------------------------------------------------------------
# All Columns:['Unnamed: 0', 'BASE_CUSTOMER_ID', 'VEHICLE_ID', 'START_DATE', 'END_DATE', 'FK_RELATION_STATUS_ID', 'FK_RELATION_STATUS_EXPLANATION']
# -------------------------------------------------------------------------------
# Columns after rename:['unnamed:_0', 'base_customer_id', 'vehicle_id', 'start_date', 'end_date', 'fk_relation_status_id', 'fk_relation_status_explanation']
# -------------------------------------------------------------------------------
# No duplicates
# -------------------------------------------------------------------------------
# We will now check the missing values and if necessary drop some columns!!!
# -------------------------------------------------------------------------------
# Shape: (374879, 7)
# 0 %, percentage of missing values of unnamed:_0 less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of base_customer_id less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of vehicle_id less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of start_date less than limit 90 %, so we will keep it.
# 215122 %, percentage of missing values of end_date less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of fk_relation_status_id less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of fk_relation_status_explanation less than limit 90 %, so we will keep it.
# New shape after missing value control: (374879, 7)

# %%
# 2-Load|Read Data
dataset_path = "D_FINAL_SALES_FILE_DATATHON.csv"
df0 = pd.read_csv(dataset_path)
df = df0.copy() 
first_looking(df)
duplicate_values(df)
drop_columns(df,[])
drop_null(df, 90)
# df.head()
# df.tail()
# df.sample(5)
# df.describe().T
# df.describe(include=object).T
# Out:
# Shape:(397526, 7)
# There is 397526 observation and 7 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397526 entries, 0 to 397525
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         397526 non-null  int64
#  1   CUSTOMER_ID        397526 non-null  int64
#  2   SALESFILE_ID       397526 non-null  float64
#  3   SF_CREATE_DATE     397526 non-null  object
#  4   STATUS             397526 non-null  int64
#  5   REQ_BRAND_CODE     397526 non-null  object
#  6   REQ_TOPMODEL_CODE  397237 non-null  float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 21.2+ MB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# Unnamed: 0           397526
# CUSTOMER_ID          183523
# SALESFILE_ID         396278
# SF_CREATE_DATE       395534
# STATUS                    6
# REQ_BRAND_CODE            5
# REQ_TOPMODEL_CODE       277
# dtype: int64
# -------------------------------------------------------------------------------
# Missing Values:
#                    Missing_Number  Missing_Percent
# REQ_TOPMODEL_CODE             289            0.001
# -------------------------------------------------------------------------------
# All Columns:['Unnamed: 0', 'CUSTOMER_ID', 'SALESFILE_ID', 'SF_CREATE_DATE', 'STATUS', 'REQ_BRAND_CODE', 'REQ_TOPMODEL_CODE']
# -------------------------------------------------------------------------------
# Columns after rename:['unnamed:_0', 'customer_id', 'salesfile_id', 'sf_create_date', 'status', 'req_brand_code', 'req_topmodel_code']
# -------------------------------------------------------------------------------
# No duplicates
# -------------------------------------------------------------------------------
# We will now check the missing values and if necessary drop some columns!!!
# -------------------------------------------------------------------------------
# Shape: (397526, 7)
# 0 %, percentage of missing values of unnamed:_0 less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of customer_id less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of salesfile_id less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of sf_create_date less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of status less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of req_brand_code less than limit 90 %, so we will keep it.
# 289 %, percentage of missing values of req_topmodel_code less than limit 90 %, so we will keep it.
# New shape after missing value control: (397526, 7)

# %%
# 2-Load|Read Data
dataset_path = "D_FINAL_SIFIR_ARAC_ALANLAR_DATATHON.csv"
df0 = pd.read_csv(dataset_path)
df = df0.copy() 
first_looking(df)
duplicate_values(df)
drop_columns(df,[])
drop_null(df, 90)
# df.head()
# df.tail()
# df.sample(5)
# df.describe().T
# df.describe(include=object).T
# Out:
# Shape:(169525, 4)
# There is 169525 observation and 4 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169525 entries, 0 to 169524
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   169525 non-null  int64
#  1   VEHICLE_ID   169525 non-null  int64
#  2   CUSTOMER_ID  169525 non-null  int64
#  3   CREATE_DATE  169525 non-null  object
# dtypes: int64(3), object(1)
# memory usage: 5.2+ MB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# Unnamed: 0     169525
# VEHICLE_ID     169521
# CUSTOMER_ID    138432
# CREATE_DATE    151242
# dtype: int64
# -------------------------------------------------------------------------------
# Missing Values:
# Empty DataFrame
# Columns: [Missing_Number, Missing_Percent]
# Index: []
# -------------------------------------------------------------------------------
# All Columns:['Unnamed: 0', 'VEHICLE_ID', 'CUSTOMER_ID', 'CREATE_DATE']
# -------------------------------------------------------------------------------
# Columns after rename:['unnamed:_0', 'vehicle_id', 'customer_id', 'create_date']
# -------------------------------------------------------------------------------
# No duplicates
# -------------------------------------------------------------------------------
# We will now check the missing values and if necessary drop some columns!!!
# -------------------------------------------------------------------------------
# Shape: (169525, 4)
# 0 %, percentage of missing values of unnamed:_0 less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of vehicle_id less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of customer_id less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of create_date less than limit 90 %, so we will keep it.
# New shape after missing value control: (169525, 4)

# %%
# 2-Load|Read Data
dataset_path = "D_FINAL_VEHICLE_TABLE_DATATHON.csv"
df0 = pd.read_csv(dataset_path)
df = df0.copy() 
first_looking(df)
duplicate_values(df)
drop_columns(df,[])
drop_null(df, 90)
# df.head()
# df.tail()
# df.sample(5)
# df.describe().T
# df.describe(include=object).T
# Out:
# Shape:(345092, 8)
# There is 345092 observation and 8 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345092 entries, 0 to 345091
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      345092 non-null  int64
#  1   VEHICLE_ID      345092 non-null  int64
#  2   TRAFFIC_DATE    344226 non-null  object
#  3   BRAND_CODE      345092 non-null  object
#  4   BASEMODEL_CODE  345092 non-null  int64
#  5   TOPMODEL_CODE   345092 non-null  int64
#  6   MOTOR_GAS_TYPE  272646 non-null  object
#  7   GEAR_BOX_TYPE   261077 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 21.1+ MB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# Unnamed: 0        345092
# VEHICLE_ID        345092
# TRAFFIC_DATE        7428
# BRAND_CODE             5
# BASEMODEL_CODE      2477
# TOPMODEL_CODE        346
# MOTOR_GAS_TYPE        10
# GEAR_BOX_TYPE         14
# dtype: int64
# -------------------------------------------------------------------------------
# Missing Values:
#                 Missing_Number  Missing_Percent
# GEAR_BOX_TYPE            84015            0.243
# MOTOR_GAS_TYPE           72446            0.210
# TRAFFIC_DATE               866            0.003
# -------------------------------------------------------------------------------
# All Columns:['Unnamed: 0', 'VEHICLE_ID', 'TRAFFIC_DATE', 'BRAND_CODE', 'BASEMODEL_CODE', 'TOPMODEL_CODE', 'MOTOR_GAS_TYPE', 'GEAR_BOX_TYPE']
# -------------------------------------------------------------------------------
# Columns after rename:['unnamed:_0', 'vehicle_id', 'traffic_date', 'brand_code', 'basemodel_code', 'topmodel_code', 'motor_gas_type', 'gear_box_type']
# -------------------------------------------------------------------------------
# No duplicates
# -------------------------------------------------------------------------------
# We will now check the missing values and if necessary drop some columns!!!
# -------------------------------------------------------------------------------
# Shape: (345092, 8)
# 0 %, percentage of missing values of unnamed:_0 less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of vehicle_id less than limit 90 %, so we will keep it.
# 866 %, percentage of missing values of traffic_date less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of brand_code less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of basemodel_code less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of topmodel_code less than limit 90 %, so we will keep it.
# 72446 %, percentage of missing values of motor_gas_type less than limit 90 %, so we will keep it.
# 84015 %, percentage of missing values of gear_box_type less than limit 90 %, so we will keep it.
# New shape after missing value control: (345092, 8)

# %%
# 2-Load|Read Data
dataset_path = "D_MASK_SERVIS_BAKIM_DATATHON_FINAL.csv"
df0 = pd.read_csv(dataset_path)
df = df0.copy() 
first_looking(df)
duplicate_values(df)
drop_columns(df,[])
drop_null(df, 90)
# df.head()
# df.tail()
# df.sample(5)
# df.describe().T
# df.describe(include=object).T
# Out:
# Shape:(1041000, 5)
# There is 1041000 observation and 5 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041000 entries, 0 to 1040999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Unnamed: 0       1041000 non-null  int64
#  1   CREATE_DATE      1041000 non-null  object
#  2   IS_MAINTENANCE   1041000 non-null  int64
#  3   VEHICLE_ID       1041000 non-null  int64
#  4   TOTAL_AMOUNT_TL  965596 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 39.7+ MB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# Unnamed: 0         1041000
# CREATE_DATE        1033883
# IS_MAINTENANCE           2
# VEHICLE_ID          225447
# TOTAL_AMOUNT_TL      16006
# dtype: int64
# -------------------------------------------------------------------------------
# Missing Values:
#                  Missing_Number  Missing_Percent
# TOTAL_AMOUNT_TL           75404            0.072
# -------------------------------------------------------------------------------
# All Columns:['Unnamed: 0', 'CREATE_DATE', 'IS_MAINTENANCE', 'VEHICLE_ID', 'TOTAL_AMOUNT_TL']
# -------------------------------------------------------------------------------
# Columns after rename:['unnamed:_0', 'create_date', 'is_maintenance', 'vehicle_id', 'total_amount_tl']
# -------------------------------------------------------------------------------
# No duplicates
# -------------------------------------------------------------------------------
# We will now check the missing values and if necessary drop some columns!!!
# -------------------------------------------------------------------------------
# Shape: (1041000, 5)
# 0 %, percentage of missing values of unnamed:_0 less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of create_date less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of is_maintenance less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of vehicle_id less than limit 90 %, so we will keep it.
# 75404 %, percentage of missing values of total_amount_tl less than limit 90 %, so we will keep it.
# New shape after missing value control: (1041000, 5)

# %%
# 2-Load|Read Data
dataset_path = "D_sample_submission.csv"
df0 = pd.read_csv(dataset_path)
df = df0.copy() 
first_looking(df)
duplicate_values(df)
drop_columns(df,[])
drop_null(df, 90)
# df.head()
# df.tail()
# df.sample(5)
# df.describe().T
# df.describe(include=object).T
# Out:
# Shape:(166943, 2)
# There is 166943 observation and 2 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166943 entries, 0 to 166942
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Id        166943 non-null  int64
#  1   Expected  0 non-null       float64
# dtypes: float64(1), int64(1)
# memory usage: 2.5 MB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# Id          166943
# Expected         0
# dtype: int64
# -------------------------------------------------------------------------------
# Missing Values:
#           Missing_Number  Missing_Percent
# Expected          166943            1.000
# -------------------------------------------------------------------------------
# All Columns:['Id', 'Expected']
# -------------------------------------------------------------------------------
# Columns after rename:['id', 'expected']
# -------------------------------------------------------------------------------
# No duplicates
# -------------------------------------------------------------------------------
# We will now check the missing values and if necessary drop some columns!!!
# -------------------------------------------------------------------------------
# Shape: (166943, 2)
# 0 %, percentage of missing values of id less than limit 90 %, so we will keep it.
# 166943 percent of expected null and were dropped
# new shape: (166943, 1)
# New shape after missing value control: (166943, 1)

# %%
print(df1_.columns)
print(df2_.columns)
print(df3_.columns)
print(df4_.columns)
print(df5_.columns)
print(df6_.columns)
print(df7_.columns)
# Out:
# Index(['Unnamed: 0', 'BASE_CUSTOMER_ID', 'CUSTOMER_ID', 'GENDER', 'GENDER_ID',
#        'MARITAL_STATUS', 'MARITAL_STATUS_ID', 'BIRTH_DATE',
#        'FK_ADDRESS_COMMUNICATION_CITY', 'OCCUPATION'],
#       dtype='object')
# Index(['Unnamed: 0', 'BASE_CUSTOMER_ID', 'VEHICLE_ID', 'START_DATE',
#        'END_DATE', 'FK_RELATION_STATUS_ID', 'FK_RELATION_STATUS_EXPLANATION'],
#       dtype='object')
# Index(['Unnamed: 0', 'CUSTOMER_ID', 'SALESFILE_ID', 'SF_CREATE_DATE', 'STATUS',
#        'REQ_BRAND_CODE', 'REQ_TOPMODEL_CODE'],
#       dtype='object')
# Index(['Unnamed: 0', 'VEHICLE_ID', 'CUSTOMER_ID', 'CREATE_DATE'], dtype='object')
# Index(['Unnamed: 0', 'VEHICLE_ID', 'TRAFFIC_DATE', 'BRAND_CODE',
#        'BASEMODEL_CODE', 'TOPMODEL_CODE', 'MOTOR_GAS_TYPE', 'GEAR_BOX_TYPE'],
#       dtype='object')
# Index(['Unnamed: 0', 'CREATE_DATE', 'IS_MAINTENANCE', 'VEHICLE_ID',
#        'TOTAL_AMOUNT_TL'],
#       dtype='object')
# Index(['Id', 'Expected'], dtype='object')

# %%
print(df1_["Unnamed: 0"])
print(df1_.shape)
print(df2_["Unnamed: 0"])
print(df2_.shape)
print(df3_["Unnamed: 0"])
print(df3_.shape)
print(df4_["Unnamed: 0"])
print(df4_.shape)
print(df5_["Unnamed: 0"])
print(df5_.shape)
print(df6_["Unnamed: 0"])
print(df6_.shape)
print(df7_.shape)
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 849914    849914
# 849915    849915
# 849916    849916
# 849917    849917
# 849918    849918
# Name: Unnamed: 0, Length: 849919, dtype: int64
# (849919, 10)
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 374874    374874
# 374875    374875
# 374876    374876
# 374877    374877
# 374878    374878
# Name: Unnamed: 0, Length: 374879, dtype: int64
# (374879, 7)
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 397521    397521
# 397522    397522
# 397523    397523
# 397524    397524
# 397525    397525
# Name: Unnamed: 0, Length: 397526, dtype: int64
# (397526, 7)
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 169520    169520
# 169521    169521
# 169522    169522
# 169523    169523
# 169524    169524
# Name: Unnamed: 0, Length: 169525, dtype: int64
# (169525, 4)
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 345087    345087
# 345088    345088
# 345089    345089
# 345090    345090
# 345091    345091
# Name: Unnamed: 0, Length: 345092, dtype: int64
# (345092, 8)
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
#             ...
# 1040995    1040995
# 1040996    1040996
# 1040997    1040997
# 1040998    1040998
# 1040999    1040999
# Name: Unnamed: 0, Length: 1041000, dtype: int64
# (1041000, 5)
# (166943, 2)

# %%
# drop_columns(df1_, 'Unnamed: 0')
# drop_columns(df2_, 'Unnamed: 0')
# drop_columns(df3_, 'Unnamed: 0')
# drop_columns(df4_, 'Unnamed: 0')
# drop_columns(df5_, 'Unnamed: 0')
# drop_columns(df6_, 'Unnamed: 0')

# %%
df1_.columns= df1_.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')
df2_.columns= df2_.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')
df3_.columns= df3_.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')
df4_.columns= df4_.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')
df5_.columns= df5_.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')
df6_.columns= df6_.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')
df7_.columns= df7_.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')

# %%
# print(df1_.columns)
# print(df2_.columns)
# print(df3_.columns)
# print(df4_.columns)
# print(df5_.columns)
# print(df6_.columns)
# print(df7_.columns)

# %%
df7_.rename({'id': 'base_customer_id'}, axis=1, inplace=True)
df7_
# Out:
#         base_customer_id  expected
# 0                 168254       NaN
# 1                 124747       NaN
# 2                 135493       NaN
# 3                  90543       NaN
# 4                  40421       NaN
# ...                  ...       ...
# 166938             53945       NaN
# 166939             98842       NaN
# 166940             55766       NaN
# 166941             22680       NaN
# 166942            154304       NaN
#
# [166943 rows x 2 columns]

# %%
drop_columns(df7_, "expected")
# expected bizim tahminleri yazacagimiz kolon suan icin dusuyoruz
# Out:
# expected were dropped

# %%
df7_.head(2)
# Out:
#    base_customer_id
# 0            168254
# 1            124747

# %%
df1_.head(2)
# Out:
#    unnamed:_0  base_customer_id  customer_id gender  gender_id marital_status  \
# 0           0            158891      1747700  Erkek        100            NaN
# 1           1            169233      1710561  Erkek        100           Evli
#
#    marital_status_id  birth_date fk_address_communication_city  \
# 0                  0         NaN                           NaN
# 1                101    1962.000                       Erzurum
#
#            occupation
# 0                 NaN
# 1  Öğretmen / Eğitmen

# %%
drop_columns(df1_, "unnamed:_0")
# unnamed:_0 indexlerden olusuyor sadece, dusuyoruz
# Out:
# unnamed:_0 were dropped

# %%
df1_
# Out:
#         base_customer_id  customer_id gender  gender_id marital_status  \
# 0                 158891      1747700  Erkek        100            NaN
# 1                 169233      1710561  Erkek        100           Evli
# 2                  30887      1043923  Erkek        100           Evli
# 3                  38013      1101926  Erkek        100            NaN
# 4                 157091      1819787  Kadın        101            NaN
# ...                  ...          ...    ...        ...            ...
# 849914             18175      1744051  Erkek        100            NaN
# 849915            108604      1209486  Erkek        100           Evli
# 849916            155926      1670812  Erkek        100           Evli
# 849917            123223      1691689  Erkek        100           Evli
# 849918             88245      1300543  Kadın        101          Bekar
#
#         marital_status_id  birth_date fk_address_communication_city  \
# 0                       0         NaN                           NaN
# 1                     101    1962.000                       Erzurum
# 2                     101    1971.000                      İstanbul
# 3                       0         NaN                        Manisa
# 4                       0         NaN                        Ankara
# ...                   ...         ...                           ...
# 849914                  0         NaN                           NaN
# 849915                101    1969.000                      İstanbul
# 849916                101    1970.000                      İstanbul
# 849917                101    1970.000                       Kayseri
# 849918                102    1966.000                      İstanbul
#
#                                 occupation
# 0                                      NaN
# 1                       Öğretmen / Eğitmen
# 2                                    Esnaf
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 849914                                 NaN
# 849915  Nakliyeci / Lojistik / Taşımacılık
# 849916                                 NaN
# 849917                                 NaN
# 849918                           Tekstilci
#
# [849919 rows x 9 columns]

# %%
df1_[["gender", "gender_id", 
     "marital_status","marital_status_id" ]].value_counts()
# Out:
# gender  gender_id  marital_status  marital_status_id
# Erkek   100        Evli            101                  447463
#                    Bekar           102                   77143
# Kadın   101        Evli            101                   65748
#                    Bekar           102                   30448
# dtype: int64

# %%
df1_["gender_id"].value_counts(dropna=False)
# Out:
# 100    731411
# 101    118505
# 0           3
# Name: gender_id, dtype: int64

# %%
df1_[df1_["gender_id"]==0]
# gender ID 0 olanlarin ikisi ayni kisi(158309) ve gender bilgisi girilmemis
# Out:
#         base_customer_id  customer_id gender  gender_id marital_status  \
# 54223             138147      1808549    NaN          0            NaN
# 368071            158309      1468162    NaN          0            NaN
# 689191            158309      1468161    NaN          0            NaN
#
#         marital_status_id  birth_date fk_address_communication_city occupation
# 54223                   0         NaN                           NaN        NaN
# 368071                  0         NaN                       Giresun        NaN
# 689191                  0         NaN                       Giresun        NaN

# %%
df1_[df1_["base_customer_id"]==158309]
# bu kisinin cinsiyeti henuz tespit edilemedigi icin nan kalacak
# Out:
#         base_customer_id  customer_id gender  gender_id marital_status  \
# 368071            158309      1468162    NaN          0            NaN
# 689191            158309      1468161    NaN          0            NaN
#
#         marital_status_id  birth_date fk_address_communication_city occupation
# 368071                  0         NaN                       Giresun        NaN
# 689191                  0         NaN                       Giresun        NaN

# %%
# df1_[df1_["base_customer_id"]==138147]
# # 138147a gender girilmemis ancak erkek oldugu goruldu

# %%
df1_.loc[(df1_["base_customer_id"]==138147), "gender"]="Erkek"
# 138147a gender girilmemis  erkek oldugu goruldu erkek olarak atandi

# %%
df1_[df1_["base_customer_id"]==138147]
# Out:
#         base_customer_id  customer_id gender  gender_id marital_status  \
# 54223             138147      1808549  Erkek          0            NaN
# 125775            138147      1823829  Erkek        100           Evli
# 312332            138147      1448732  Erkek        100           Evli
# 325514            138147      1822401  Erkek        100           Evli
# 370518            138147      1822818  Erkek        100           Evli
# 485788            138147      1392445  Erkek        100           Evli
# 641593            138147      1801401  Erkek        100            NaN
# 690934            138147      1392446  Erkek        100           Evli
# 845285            138147      1747889  Erkek        100           Evli
#
#         marital_status_id  birth_date fk_address_communication_city  \
# 54223                   0         NaN                           NaN
# 125775                101    1981.000                       Isparta
# 312332                101    1981.000                       Isparta
# 325514                101    1981.000                       Isparta
# 370518                101    1981.000                       Isparta
# 485788                101    1981.000                        Burdur
# 641593                  0         NaN                       Isparta
# 690934                101    1981.000                       Isparta
# 845285                101    1981.000                       Isparta
#
#                          occupation
# 54223                           NaN
# 125775                      Serbest
# 312332                        Esnaf
# 325514                      Serbest
# 370518                        Esnaf
# 485788                          NaN
# 641593                          NaN
# 690934                      Serbest
# 845285  Oto. Bayisi / Oto. Galerisi

# %%
df1_.loc[(df1_["base_customer_id"]==138147), "gender_id"]=100
# 138147a gender girilmemis  erkek oldugu goruldu erkek olarak atandi

# %%
df1_[df1_["base_customer_id"]==138147]
# Out:
#         base_customer_id  customer_id gender  gender_id marital_status  \
# 54223             138147      1808549  Erkek        100            NaN
# 125775            138147      1823829  Erkek        100           Evli
# 312332            138147      1448732  Erkek        100           Evli
# 325514            138147      1822401  Erkek        100           Evli
# 370518            138147      1822818  Erkek        100           Evli
# 485788            138147      1392445  Erkek        100           Evli
# 641593            138147      1801401  Erkek        100            NaN
# 690934            138147      1392446  Erkek        100           Evli
# 845285            138147      1747889  Erkek        100           Evli
#
#         marital_status_id  birth_date fk_address_communication_city  \
# 54223                   0         NaN                           NaN
# 125775                101    1981.000                       Isparta
# 312332                101    1981.000                       Isparta
# 325514                101    1981.000                       Isparta
# 370518                101    1981.000                       Isparta
# 485788                101    1981.000                        Burdur
# 641593                  0         NaN                       Isparta
# 690934                101    1981.000                       Isparta
# 845285                101    1981.000                       Isparta
#
#                          occupation
# 54223                           NaN
# 125775                      Serbest
# 312332                        Esnaf
# 325514                      Serbest
# 370518                        Esnaf
# 485788                          NaN
# 641593                          NaN
# 690934                      Serbest
# 845285  Oto. Bayisi / Oto. Galerisi

# %%
df1_.shape
# Out:
# (849919, 9)

# %%
# ((df1_["gender_id"]==100)&(df1_["gender"]=="Erkek")).value_counts()

# %%
## ((df1_["gender_id"]==101)&(df1_["gender"]=="Kadın")).value_counts()
# 101 olanlarin kadin oldugu teyit edildi
# 100 olanlarin erkek oldugu teyit edildi
# dolayisi ile gender idyi dusuyoruz

# %%
drop_columns(df1_, "gender_id")
# gender IDyi dustuk ancak genderda ik adet NAN kaldi simdilik
# Out:
# gender_id were dropped

# %%
df1_.head(2)
# Out:
#    base_customer_id  customer_id gender marital_status  marital_status_id  \
# 0            158891      1747700  Erkek            NaN                  0
# 1            169233      1710561  Erkek           Evli                101
#
#    birth_date fk_address_communication_city          occupation
# 0         NaN                           NaN                 NaN
# 1    1962.000                       Erzurum  Öğretmen / Eğitmen

# %%
df1_["marital_status_id"].value_counts(dropna=False)
# Out:
# 101    513211
# 0      229117
# 102    107591
# Name: marital_status_id, dtype: int64

# %%
df1_["marital_status"].value_counts(dropna=False)
# Out:
# Evli     513211
# NaN      229117
# Bekar    107591
# Name: marital_status, dtype: int64

# %%
((df1_["marital_status_id"]==101)&(df1_["marital_status"]=="Evli")).value_counts()
# Out:
# True     513211
# False    336708
# dtype: int64

# %%
((df1_["marital_status_id"]==102)&(df1_["marital_status"]=="Bekar")).value_counts()
# 101 olanlarin Evli oldugu teyit edildi
# 102 olanlarin Bekar oldugu teyit edildi
# 0 olanlarin NaN oldugu teyit edildi
# dolayisi ile marital_status_idyi dusuyoruz
# Out:
# False    742328
# True     107591
# dtype: int64

# %%
drop_columns(df1_, "marital_status_id")
# marital_status_idyi dustuk ancak genderda ik adet NAN kaldi simdilik
# Out:
# marital_status_id were dropped

# %%
df1_.head(2)
# Out:
#    base_customer_id  customer_id gender marital_status  birth_date  \
# 0            158891      1747700  Erkek            NaN         NaN
# 1            169233      1710561  Erkek           Evli    1962.000
#
#   fk_address_communication_city          occupation
# 0                           NaN                 NaN
# 1                       Erzurum  Öğretmen / Eğitmen

# %%
df1_.shape
# Out:
# (849919, 7)

# %%
df7_.head(2)
# Out:
#    base_customer_id
# 0            168254
# 1            124747

# %%
df7_.shape
# Out:
# (166943, 1)

# %%
df_ = df7_.merge(df1_, on="base_customer_id", how='left')

df_.head(2)
# Out:
#    base_customer_id  customer_id gender marital_status  birth_date  \
# 0            168254      1507435  Erkek          Bekar    1988.000
# 1            168254      1663507  Erkek          Bekar    1988.000
#
#   fk_address_communication_city occupation
# 0                     Şanlıurfa        NaN
# 1                     Şanlıurfa        NaN

# %%
df_.shape
# Out:
# (714249, 7)

# %%
849919-714249
# df1deki 135670 adet veri girisi bizim sample_submission yapacagimiz kisilere ait degil
# Out:
# 135670

# %%
df2_["fk_relation_status_explanation"].value_counts()
# Out:
# Aktif Ruhsat Sahibi    215122
# Pasif Ruhsat Sahibi    159757
# Name: fk_relation_status_explanation, dtype: int64

# %%
df2__ = df2_[df2_["fk_relation_status_explanation"]=="Aktif Ruhsat Sahibi"]["base_customer_id"].unique()

# %%
len(df2__)
# Out:
# 166943

# %%
np.sort(df2__)
# Out:
# array([     1,      2,      3, ..., 196559, 196560, 196563], dtype=int64)

# %%
df7_["base_customer_id"].sort_values().head(3)
# Out:
# 40570     1
# 131267    2
# 68238     3
# Name: base_customer_id, dtype: int64

# %%
df7_["base_customer_id"].sort_values().tail(3)
# Out:
# 141974    196559
# 92600     196560
# 148887    196563
# Name: base_customer_id, dtype: int64

# %%
len(df7_)
# Out:
# 166943

# %%
(np.sort(df2__)==df7_["base_customer_id"].sort_values()).value_counts()
# df7_ ile df2_ deki BCIDler birebir ayni, sorun yok; df2_'de 166943 unique BCID ve 
# bu kisilere ait toplam 215122 adet aktif ruhsatli arac ve bu araclarin VehicleIDleri var, 
# ayrica yine bu kisilere ait 309000-215122 adet Pasif Ruhsatli arac ve bu araclarin VehicleIDleri var.
# Out:
# True    166943
# Name: base_customer_id, dtype: int64

# %%
df2_[df2_["fk_relation_status_explanation"]=="Aktif Ruhsat Sahibi"][["base_customer_id","vehicle_id"]]
# df2_ 166943 unique BCID ve 
# bu kisilere ait toplam 215122 adet aktif ruhsatli arac ve VehicleIDleri var 
# en eonemli kitle hem kapali hem acik ruhsatli arac bilgisi olan bu kisiler olabilir
# Out:
#         base_customer_id  vehicle_id
# 1                 110802     5329278
# 2                 160615     5329282
# 3                 115664     5328513
# 4                  81061     5322264
# 5                 127152     5322205
# ...                  ...         ...
# 374870            168053     5179442
# 374874            154304     5179455
# 374875             75199     5180458
# 374876              9036     5177679
# 374877             33936     5172864
#
# [215122 rows x 2 columns]

# %%
df2_["fk_relation_status_explanation"].value_counts(dropna=False)
# Out:
# Aktif Ruhsat Sahibi    215122
# Pasif Ruhsat Sahibi    159757
# Name: fk_relation_status_explanation, dtype: int64

# %%
df2_.shape
# Out:
# (374879, 7)

# %%
df2_["base_customer_id"].nunique()
# Out:
# 196538

# %%
# df2_.groupby("base_customer_id")["fk_relation_status_explanation"].describe(include=object)

# %%
df2_[df2_["fk_relation_status_explanation"]=="Aktif Ruhsat Sahibi"]
# Out:
#         unnamed:_0  base_customer_id  vehicle_id  start_date end_date  \
# 1                1            110802     5329278  2019-07-16      NaN
# 2                2            160615     5329282  2019-09-12      NaN
# 3                3            115664     5328513  2019-02-25      NaN
# 4                4             81061     5322264  2018-04-16      NaN
# 5                5            127152     5322205  2021-04-12      NaN
# ...            ...               ...         ...         ...      ...
# 374870      374870            168053     5179442  2013-06-25      NaN
# 374874      374874            154304     5179455  2010-10-19      NaN
# 374875      374875             75199     5180458  2019-01-02      NaN
# 374876      374876              9036     5177679  2012-05-28      NaN
# 374877      374877             33936     5172864  2014-08-16      NaN
#
#         fk_relation_status_id fk_relation_status_explanation
# 1                           1            Aktif Ruhsat Sahibi
# 2                           1            Aktif Ruhsat Sahibi
# 3                           1            Aktif Ruhsat Sahibi
# 4                           1            Aktif Ruhsat Sahibi
# 5                           1            Aktif Ruhsat Sahibi
# ...                       ...                            ...
# 374870                      1            Aktif Ruhsat Sahibi
# 374874                      1            Aktif Ruhsat Sahibi
# 374875                      1            Aktif Ruhsat Sahibi
# 374876                      1            Aktif Ruhsat Sahibi
# 374877                      1            Aktif Ruhsat Sahibi
#
# [215122 rows x 7 columns]

# %%
df2_[df2_["fk_relation_status_explanation"]=="Pasif Ruhsat Sahibi"]
# Out:
#         unnamed:_0  base_customer_id  vehicle_id  start_date    end_date  \
# 0                0            189537     5321560  2018-07-24  2019-07-03
# 6                6            153835     5322205  2018-06-05  2019-06-21
# 10              10            164581     5321370  2020-04-29  2020-08-07
# 11              11            111788     5321488  2018-02-07  2019-02-26
# 16              16            154311     5326120  2018-10-31  2019-12-11
# ...            ...               ...         ...         ...         ...
# 374869      374869            168053     5179442  2010-09-14  2011-11-24
# 374871      374871             93551     5188087  2019-06-26  2019-06-29
# 374872      374872            157467     5188087  2013-07-22  2014-06-12
# 374873      374873            133546     5178752  2014-01-31  2014-03-19
# 374878      374878             91144     5189133  2012-01-13  2013-01-25
#
#         fk_relation_status_id fk_relation_status_explanation
# 0                           2            Pasif Ruhsat Sahibi
# 6                           2            Pasif Ruhsat Sahibi
# 10                          2            Pasif Ruhsat Sahibi
# 11                          2            Pasif Ruhsat Sahibi
# 16                          2            Pasif Ruhsat Sahibi
# ...                       ...                            ...
# 374869                      2            Pasif Ruhsat Sahibi
# 374871                      2            Pasif Ruhsat Sahibi
# 374872                      2            Pasif Ruhsat Sahibi
# 374873                      2            Pasif Ruhsat Sahibi
# 374878                      2            Pasif Ruhsat Sahibi
#
# [159757 rows x 7 columns]

# %%
df2_aktifID = df2_[df2_["fk_relation_status_explanation"]=="Aktif Ruhsat Sahibi"]["base_customer_id"]
df2_aktifID
# Out:
# 1         110802
# 2         160615
# 3         115664
# 4          81061
# 5         127152
#            ...
# 374870    168053
# 374874    154304
# 374875     75199
# 374876      9036
# 374877     33936
# Name: base_customer_id, Length: 215122, dtype: int64

# %%
df2_pasifID = df2_[df2_["fk_relation_status_explanation"]=="Pasif Ruhsat Sahibi"]["base_customer_id"]
df2_pasifID
# Out:
# 0         189537
# 6         153835
# 10        164581
# 11        111788
# 16        154311
#            ...
# 374869    168053
# 374871     93551
# 374872    157467
# 374873    133546
# 374878     91144
# Name: base_customer_id, Length: 159757, dtype: int64

# %%
df_diff = pd.concat([df2_aktifID , df2_pasifID ]).drop_duplicates(keep=False)
df_diff
# Out:
# 1         110802
# 5         127152
# 8          59160
# 9         159897
# 15        177011
#            ...
# 374781     78413
# 374826     61332
# 374838    119487
# 374866    163801
# 374871     93551
# Name: base_customer_id, Length: 106685, dtype: int64

# %%
df2_["fk_relation_status_explanation"].value_counts(dropna=False)
# Out:
# Aktif Ruhsat Sahibi    215122
# Pasif Ruhsat Sahibi    159757
# Name: fk_relation_status_explanation, dtype: int64

# %%
df2_["base_customer_id"].nunique()
# Out:
# 196538

# %%
df2_.shape
# Out:
# (374879, 7)

# %%
df2_target_customer = pd.merge(df2_aktifID, df2_pasifID, how='inner')
df2_target_customer
# Out:
#         base_customer_id
# 0                 160615
# 1                 160615
# 2                 160615
# 3                 160615
# 4                 160615
# ...                  ...
# 410450             33936
# 410451             33936
# 410452             33936
# 410453             33936
# 410454             33936
#
# [410455 rows x 1 columns]

# %%
df2_target_customer.nunique()
# Out:
# base_customer_id    56162
# dtype: int64

# %%
len(set(df2_target_customer["base_customer_id"]))
# hem pasif hem de aktif araci olan bizim potansiyel arac alacagini dusundugumuz kitlenin base customer idileri
# Out:
# 56162

# %%
df2_[df2_["base_customer_id"]==185023]
# Out:
#         unnamed:_0  base_customer_id  vehicle_id  start_date    end_date  \
# 1174          1174            185023     5251358  2015-08-17  2015-10-19
# 2009          2009            185023     5181366  2014-11-26         NaN
# 2230          2230            185023     5073008  2014-05-13         NaN
# 3076          3076            185023     5186431  2014-03-28         NaN
# 3443          3443            185023     5071744  2015-01-26  2017-09-22
# 3763          3763            185023     5037241  2014-11-20         NaN
# 6248          6248            185023     5037598  2013-06-12         NaN
# 7685          7685            185023     5210677  2014-09-09  2020-03-23
# 7809          7809            185023     5173981  2013-05-30         NaN
# 8659          8659            185023     5088327  2015-12-03         NaN
# 9838          9838            185023     5032442  2012-08-15         NaN
# 10997        10997            185023     5210676  2014-09-05         NaN
# 11035        11035            185023     5185558  2014-10-31         NaN
# 11074        11074            185023     5175889  2013-03-25  2019-09-19
# 12571        12571            185023     5086720  2013-04-16         NaN
# 13105        13105            185023     5162888  2015-08-18  2018-02-26
# 13822        13822            185023     5069412  2013-03-11         NaN
# 15920        15920            185023     5269750  2015-10-27  2016-04-08
# 16250        16250            185023     5206402  2016-02-10  2016-02-27
# 16261        16261            185023     5219402  2016-01-29  2016-06-14
# 17117        17117            185023     5268696  2015-12-23  2019-04-10
# 17211        17211            185023     5218933  2015-09-01  2017-07-26
# 18973        18973            185023     5185772  2015-09-08         NaN
# 19009        19009            185023     5175055  2014-10-21  2015-03-17
# 21132        21132            185023     5061043  2013-01-29  2013-06-01
# 21852        21852            185023     5162304  2015-04-07         NaN
# 21891        21891            185023     5168129  2016-01-15  2016-02-29
# 22458        22458            185023     5001737  2015-09-08         NaN
# 22701        22701            185023     5084813  2013-04-19         NaN
# 24129        24129            185023     5072253  2013-01-31  2020-10-27
# 26650        26650            185023     5242248  2016-01-21  2016-10-14
# 27026        27026            185023     5161077  2012-10-04  2013-01-16
# 27545        27545            185023     5162473  2016-09-28         NaN
# 33808        33808            185023     5245042  2015-03-13  2015-07-08
# 35257        35257            185023     5003813  2012-08-02         NaN
# 35827        35827            185023     5163630  2015-12-09  2017-08-24
# 37186        37186            185023     5170804  2014-12-23  2015-07-24
# 38604        38604            185023     5059051  2014-04-03         NaN
# 41965        41965            185023     5049765  2016-05-03  2016-05-25
# 42488        42488            185023     5142410  2014-12-10         NaN
# 334132      334132            185023     5220976  2014-11-20  2015-04-20
# 336803      336803            185023     5140302  2014-09-09  2015-03-26
# 337923      337923            185023     5189669  2014-10-14  2015-02-28
# 339293      339293            185023     5257452  2015-10-26  2015-11-27
# 339313      339313            185023     5254780  2015-10-27  2015-11-26
# 339545      339545            185023     5058275  2012-12-27         NaN
# 339588      339588            185023     5221013  2014-07-04  2014-08-05
# 341508      341508            185023     5138760  2014-05-08         NaN
# 341952      341952            185023     5137801  2013-09-17  2013-09-28
# 342307      342307            185023     5160087  2015-04-07         NaN
# 342342      342342            185023     5015564  2013-08-01  2013-09-02
# 342396      342396            185023     5065890  2014-10-31         NaN
# 343374      343374            185023     5001813  2016-02-04  2016-02-16
# 343466      343466            185023     5157603  2015-03-30  2016-12-20
# 344773      344773            185023     5135024  2014-07-22         NaN
# 344846      344846            185023     5201677  2015-04-15  2018-05-21
# 345622      345622            185023     5126921  2016-09-26  2016-10-01
# 346093      346093            185023     5220327  2015-01-27  2017-05-26
# 346747      346747            185023     5154624  2013-02-05         NaN
# 347498      347498            185023     5148964  2015-07-08         NaN
# 347608      347608            185023     5199912  2014-04-15         NaN
# 347622      347622            185023     5191556  2014-09-30  2015-07-31
# 348929      348929            185023     5197255  2014-09-23         NaN
# 349812      349812            185023     5141110  2014-08-13         NaN
# 351260      351260            185023     5191275  2014-10-22         NaN
# 351310      351310            185023     5139698  2012-09-26         NaN
# 351367      351367            185023     5149782  2015-09-14  2020-09-16
# 352605      352605            185023     5187339  2013-03-26         NaN
# 354521      354521            185023     5045048  2015-06-11         NaN
# 360375      360375            185023     5172612  2013-12-27         NaN
# 360896      360896            185023     5204076  2014-04-29  2014-10-25
# 361870      361870            185023     5222259  2015-06-18  2016-10-18
# 362407      362407            185023     5129139  2012-12-20         NaN
# 362854      362854            185023     5140199  2015-08-20  2016-08-02
# 363425      363425            185023     5147909  2013-08-01         NaN
# 363429      363429            185023     5147888  2013-09-24         NaN
# 364328      364328            185023     5234032  2018-04-11         NaN
# 366742      366742            185023     5179795  2012-10-10         NaN
# 367288      367288            185023     5202532  2015-10-07         NaN
# 367985      367985            185023     5043661  2012-08-23         NaN
# 368310      368310            185023     5194000  2014-12-15  2015-08-06
# 369994      369994            185023     5144893  2014-09-09  2015-12-18
# 370159      370159            185023     5101643  2012-08-02         NaN
# 372588      372588            185023     5112589  2015-12-24         NaN
# 374504      374504            185023     5134329  2015-03-09         NaN
# 374628      374628            185023     5135306  2013-07-31         NaN
#
#         fk_relation_status_id fk_relation_status_explanation
# 1174                        2            Pasif Ruhsat Sahibi
# 2009                        1            Aktif Ruhsat Sahibi
# 2230                        1            Aktif Ruhsat Sahibi
# 3076                        1            Aktif Ruhsat Sahibi
# 3443                        2            Pasif Ruhsat Sahibi
# 3763                        1            Aktif Ruhsat Sahibi
# 6248                        1            Aktif Ruhsat Sahibi
# 7685                        2            Pasif Ruhsat Sahibi
# 7809                        1            Aktif Ruhsat Sahibi
# 8659                        1            Aktif Ruhsat Sahibi
# Aktif Ruhsat Sahibi    215122
# Pasif Ruhsat Sahibi    159757
# Name: fk_relation_status_explanation, dtype: int64

# %%
df2_[df2_["fk_relation_status_explanation"]=="Aktif Ruhsat Sahibi"]["base_customer_id"].nunique()
# Out:
# 166943

# %%
df2_[df2_["fk_relation_status_explanation"]=="Pasif Ruhsat Sahibi"]["base_customer_id"].nunique()
# Out:
# 85757

# %%
df_.head(2)
# Out:
#    base_customer_id  customer_id gender marital_status  birth_date  \
# 0            168254      1507435  Erkek          Bekar    1988.000
# 1            168254      1663507  Erkek          Bekar    1988.000
#
#   fk_address_communication_city occupation
# 0                     Şanlıurfa        NaN
# 1                     Şanlıurfa        NaN

# %%
df2_.head(2)
# Out:
#    unnamed:_0  base_customer_id  vehicle_id  start_date    end_date  \
# 0           0            189537     5321560  2018-07-24  2019-07-03
# 1           1            110802     5329278  2019-07-16         NaN
#
#    fk_relation_status_id fk_relation_status_explanation
# 0                      2            Pasif Ruhsat Sahibi
# 1                      1            Aktif Ruhsat Sahibi

# %%
df2_["fk_relation_status_id"].value_counts(dropna=False)
# Out:
# 1    215122
# 2    159757
# Name: fk_relation_status_id, dtype: int64

# %%
((df2_["fk_relation_status_id"]==1)&(df2_["fk_relation_status_explanation"]=="Aktif Ruhsat Sahibi")).value_counts()
# Out:
# True     215122
# False    159757
# dtype: int64

# %%
((df2_["fk_relation_status_id"]==2)&(df2_["fk_relation_status_explanation"]=="Pasif Ruhsat Sahibi")).value_counts()
# 1 olanlarin Aktif Ruhsat Sahibi oldugu teyit edildi
# 2 olanlarin Pasif Ruhsat Sahibi oldugu teyit edildi
# dolayisi ile fk_relation_status_idyi dusuyoruz
# unnamed:_0 da dusuyoruz
# Out:
# False    215122
# True     159757
# dtype: int64

# %%
drop_columns(df2_, ["fk_relation_status_id", "unnamed:_0"])
# Out:
# ['fk_relation_status_id', 'unnamed:_0'] were dropped

# %%
df2_.head(2)
# Out:
#    base_customer_id  vehicle_id  start_date    end_date  \
# 0            189537     5321560  2018-07-24  2019-07-03
# 1            110802     5329278  2019-07-16         NaN
#
#   fk_relation_status_explanation
# 0            Pasif Ruhsat Sahibi
# 1            Aktif Ruhsat Sahibi

# %%
df_.shape
# df7_ ve df1_ join edilmisti suana kadar
# Out:
# (714249, 7)

# %%
df2_.shape
# Out:
# (374879, 5)

# %%
df_.head(2)
# Out:
#    base_customer_id  customer_id gender marital_status  birth_date  \
# 0            168254      1507435  Erkek          Bekar    1988.000
# 1            168254      1663507  Erkek          Bekar    1988.000
#
#   fk_address_communication_city occupation
# 0                     Şanlıurfa        NaN
# 1                     Şanlıurfa        NaN

# %%
df_ = df_.merge(df2_, on="base_customer_id", how='left')
df_.head(2)
# Out:
#    base_customer_id  customer_id gender marital_status  birth_date  \
# 0            168254      1507435  Erkek          Bekar    1988.000
# 1            168254      1507435  Erkek          Bekar    1988.000
#
#   fk_address_communication_city occupation  vehicle_id  start_date  \
# 0                     Şanlıurfa        NaN     5329232  2019-09-20
# 1                     Şanlıurfa        NaN     5183621  2015-09-14
#
#      end_date fk_relation_status_explanation
# 0         NaN            Aktif Ruhsat Sahibi
# 1  2019-07-05            Pasif Ruhsat Sahibi

# %%
df_["base_customer_id"].nunique()
# Out:
# 166943

# %%
df3_.head(2)
# Out:
#    unnamed:_0  customer_id  salesfile_id       sf_create_date  status  \
# 0           0      1712792   7274467.000  2017-11-17 12:15:39     101
# 1           1      1149729   4839430.000  2015-11-11 17:03:28     102
#
#   req_brand_code  req_topmodel_code
# 0              Y           9231.000
# 1              K           9184.000

# %%
df3_.shape
# Out:
# (397526, 7)

# %%
df4_.head()
# Out:
#    unnamed:_0  vehicle_id  customer_id          create_date
# 0           0     5015193      1063740  2005-01-01 19:08:33
# 1           1     5110231      1155678  2005-09-29 17:16:15
# 2           2     5290356      1737831  2016-04-29 13:12:10
# 3           3     5344576      1841362  2021-03-16 13:39:01
# 4           4     5094010      1066916  2005-04-20 09:51:19

# %%
df4_.shape
# Out:
# (169525, 4)

# %%
df5_.head()
# Out:
#    unnamed:_0  vehicle_id traffic_date brand_code  basemodel_code  \
# 0           0     5317713   2017-12-07          Z           13398
# 1           1     5259212   2014-12-09          X           15694
# 2           2     5110414   2005-12-12          Y           11183
# 3           3     5101263   2005-08-23          X           15039
# 4           4     5053909   2003-04-09          Y           12255
#
#    topmodel_code    motor_gas_type   gear_box_type
# 0           9349            Benzin          Manuel
# 1           9524             Dizel  Otomatik (DSG)
# 2           9118  Kurşunsuz Benzin        Otomatik
# 3           9495            Benzin          Manuel
# 4           9219               NaN             NaN

# %%
df5_.shape
# Out:
# (345092, 8)

# %%
df6_.head()
# Out:
#    unnamed:_0          create_date  is_maintenance  vehicle_id  \
# 0           0  2010-12-29 10:50:56               1     5000001
# 1           1  2013-08-21 10:34:21               1     5000001
# 2           2  2015-11-30 10:55:00               1     5000001
# 3           3  2015-12-09 13:38:49               0     5000001
# 4           4  2017-11-23 09:53:22               1     5000001
#
#    total_amount_tl
# 0          192.000
# 1          267.000
# 2         1747.000
# 3          465.000
# 4          549.000

# %%
df6_.shape
# Out:
# (1041000, 5)

# %%
df6_vehicle = df6_["vehicle_id"]

# %%
df4_vehicle = df4_["vehicle_id"]

# %%
df_diff = pd.concat([df2_vehicle, df4_vehicle]).drop_duplicates(keep=False)
df_diff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-c9a55aa22d54> in <module>
# ----> 1 df_diff = pd.concat([df2_vehicle, df4_vehicle]).drop_duplicates(keep=False)
#       2 df_diff
#
# NameError: name 'df2_vehicle' is not defined

# %%
df_diff = pd.concat([df2_vehicle, df5_vehicle]).drop_duplicates(keep=False)
df_diff

# %%
df5_vehicle = df5_["vehicle_id"]

# %%
df2_vehicle.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-6f5e9da76cb1> in <module>
# ----> 1 df2_vehicle.shape
#
# NameError: name 'df2_vehicle' is not defined

# %%
df6_vehicle.shape
# Out:
# (1041000,)

# %%
df6_vehicle.nunique()
# Out:
# 225447

# %%
df2_vehicle.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-118-43dae4033d8a> in <module>
# ----> 1 df2_vehicle.nunique()
#
# NameError: name 'df2_vehicle' is not defined

# %%
df_diff = pd.concat([df2_vehicle, df6_vehicle]).drop_duplicates(keep=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-3bca5873e094> in <module>
# ----> 1 df_diff = pd.concat([df2_vehicle, df6_vehicle]).drop_duplicates(keep=False)
#
# NameError: name 'df2_vehicle' is not defined

# %%
df_diff
# Out:
# 1         110802
# 5         127152
# 8          59160
# 9         159897
# 15        177011
#            ...
# 374781     78413
# 374826     61332
# 374838    119487
# 374866    163801
# 374871     93551
# Name: base_customer_id, Length: 106685, dtype: int64

# %%
df2_
# Out:
#         base_customer_id  vehicle_id  start_date    end_date  \
# 0                 189537     5321560  2018-07-24  2019-07-03
# 1                 110802     5329278  2019-07-16         NaN
# 2                 160615     5329282  2019-09-12         NaN
# 3                 115664     5328513  2019-02-25         NaN
# 4                  81061     5322264  2018-04-16         NaN
# ...                  ...         ...         ...         ...
# 374874            154304     5179455  2010-10-19         NaN
# 374875             75199     5180458  2019-01-02         NaN
# 374876              9036     5177679  2012-05-28         NaN
# 374877             33936     5172864  2014-08-16         NaN
# 374878             91144     5189133  2012-01-13  2013-01-25
#
#        fk_relation_status_explanation
# 0                 Pasif Ruhsat Sahibi
# 1                 Aktif Ruhsat Sahibi
# 2                 Aktif Ruhsat Sahibi
# 3                 Aktif Ruhsat Sahibi
# 4                 Aktif Ruhsat Sahibi
# ...                               ...
# 374874            Aktif Ruhsat Sahibi
# 374875            Aktif Ruhsat Sahibi
# 374876            Aktif Ruhsat Sahibi
# 374877            Aktif Ruhsat Sahibi
# 374878            Pasif Ruhsat Sahibi
#
# [374879 rows x 5 columns]

# %%
df6_.shape
# Out:
# (1041000, 5)

# %%
df_vehicle=df_["vehicle_id"]

# %%
df_diff = pd.concat([df_vehicle, df6_vehicle]).drop_duplicates(keep=False)
df_diff
# Out:
# 9619       5018539
# 10335      5004562
# 10355      5005050
# 11569      5018325
# 14039      5111440
#             ...
# 1040162    5341922
# 1040278    5342204
# 1040389    5342626
# 1040508    5342903
# 1040971    5344784
# Name: vehicle_id, Length: 9808, dtype: int64

# %%
df_ = df_.merge(df2_, on = "base_customer_id", how='left')
df_["base_customer_id"].nunique()
# df7_+df_1(BaseCustID)+df3_(CustomerID)
# Out:
# 166943

# %%
df2_aktif = df2_[df2_["fk_relation_status_explanation"]=="Aktif Ruhsat Sahibi"]["base_customer_id"]
df2_aktif
# Out:
# 1         110802
# 2         160615
# 3         115664
# 4          81061
# 5         127152
#            ...
# 374870    168053
# 374874    154304
# 374875     75199
# 374876      9036
# 374877     33936
# Name: base_customer_id, Length: 215122, dtype: int64

# %%
df2_pasif = df2_[df2_["fk_relation_status_explanation"]=="Pasif Ruhsat Sahibi"]["base_customer_id"]
df2_pasif
# Out:
# 0         189537
# 6         153835
# 10        164581
# 11        111788
# 16        154311
#            ...
# 374869    168053
# 374871     93551
# 374872    157467
# 374873    133546
# 374878     91144
# Name: base_customer_id, Length: 159757, dtype: int64

# %%
df2_.shape
# Out:
# (374879, 5)

# %%
df_diff = pd.concat([df2_pasif, df2_aktif]).drop_duplicates(keep=False)
df_diff
# Out:
# 131        55526
# 175       194513
# 183       183147
# 188       192492
# 196       180052
#            ...
# 374834    104036
# 374842    155760
# 374858     22680
# 374863    124954
# 374865    167802
# Name: base_customer_id, Length: 106685, dtype: int64

# %%
159757-106685
# Out:
# 53072

# %%
df_.shape
# Out:
# (28440948, 15)

# %%
df_.head()
# Out:
#    base_customer_id  customer_id gender marital_status  birth_date  \
# 0            168254      1507435  Erkek          Bekar    1988.000
# 1            168254      1507435  Erkek          Bekar    1988.000
# 2            168254      1507435  Erkek          Bekar    1988.000
# 3            168254      1507435  Erkek          Bekar    1988.000
# 4            168254      1507435  Erkek          Bekar    1988.000
#
#   fk_address_communication_city occupation  vehicle_id_x start_date_x  \
# 0                     Şanlıurfa        NaN       5329232   2019-09-20
# 1                     Şanlıurfa        NaN       5329232   2019-09-20
# 2                     Şanlıurfa        NaN       5329232   2019-09-20
# 3                     Şanlıurfa        NaN       5329232   2019-09-20
# 4                     Şanlıurfa        NaN       5329232   2019-09-20
#
#   end_date_x fk_relation_status_explanation_x  vehicle_id_y start_date_y  \
# 0        NaN              Aktif Ruhsat Sahibi       5329232   2019-09-20
# 1        NaN              Aktif Ruhsat Sahibi       5183621   2015-09-14
# 2        NaN              Aktif Ruhsat Sahibi       5208488   2012-09-15
# 3        NaN              Aktif Ruhsat Sahibi       5310923   2018-07-19
# 4        NaN              Aktif Ruhsat Sahibi       5311914   2019-03-29
#
#    end_date_y fk_relation_status_explanation_y
# 0         NaN              Aktif Ruhsat Sahibi
# 1  2019-07-05              Pasif Ruhsat Sahibi
# 2  2014-02-19              Pasif Ruhsat Sahibi
# 3  2019-08-16              Pasif Ruhsat Sahibi
# 4  2021-02-10              Pasif Ruhsat Sahibi

# %%
df_ = df_.merge(df6_, on = "vehicle_id", how='left')
df_["base_customer_id"].nunique()
# df7_+df_1(BaseCustID)+df3_(CustomerID)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-bfe5cec959d7> in <module>
# ----> 1 df_ = df_.merge(df6_, on = "vehicle_id", how='left')
#       2 df_["base_customer_id"].nunique()
#       3 # df7_+df_1(BaseCustID)+df3_(CustomerID)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8193         from pandas.core.reshape.merge import merge
#    8194
# -> 8195         return merge(
#    8196             self,
#    8197             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     666             self.right_join_keys,
#     667             self.join_names,
# --> 668         ) = self._get_merge_keys()
#     669
#     670         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1044                         right_keys.append(rk)
#    1045                     if lk is not None:
# -> 1046                         left_keys.append(left._get_label_or_level_values(lk))
#    1047                         join_names.append(lk)
#    1048                     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'vehicle_id'

# %%
df_.shape

# %%
df_.head()

# %%
df_["vehicle_id"].nunique()

# %%
df_[(df_["base_customer_id"].notnull())&(df_["vehicle_id"].isnull())]["base_customer_id"]

# %%
df_vehicle = df_["vehicle_id"]

# %%
df_diff = pd.concat([df_vehicle, df2_vehicle]).drop_duplicates(keep=False)
df_diff

# %%
df_[df_["vehicle_id"]==5124447]

# %%
df6_[df6_["vehicle_id"]==5124447]

# %%
df6_[df6_["vehicle_id"]==5095487]

# %%
df6_[df6_["vehicle_id"]==5009220]

# %%
df6_[df6_["vehicle_id"]==5251191]

# %%
df2_vehicle[df2_vehicle==5251191]

# %%
df_[df_["vehicle_id"]==5251191]

# %%
df_["fk_relation_status_explanation"].value_counts()

# %%
df_vehicle.nunique()

# %%
df2_vehicle.nunique()

# %%
df2_.info()

# %%
len(df_)

# %%
df_[["base_customer_id","vehicle_id"]].value_counts()

# %%
df2_vehicle

# %%
df2_.shape

# %%
df4_.head(2)

# %%
df4_.shape

# %%
df_ = df_.merge(df2_, on = "base_customer_id", how='left')
df_["base_customer_id"].nunique()
# df7_+df_1(BaseCustID)+df3_(CustomerID)

# %%
drop_columns(df_, ["expected", "unnamed:_0_x", "unnamed:_0_y"])

# %%
df_.head()

# %%
df_ = df_.merge(df3_, on = "customer_id", how='left')
df_["base_customer_id"].nunique()

# %%
df_.shape

# %%
df4_.head()

# %%
df_ = df_.merge(df4_, on = "customer_id", how='left')
df_["base_customer_id"].nunique()

# %%
df.head(2)

# %%
df_.head(2)

# %%
df1_.head(2)

# %%
df2_.head(2)

# %%
df3_.head(2)

# %%
df4_.head(2)

# %%
df5_.head(2)

# %%
df6_.head(2)

# %%
df7_.head(2)

# %%
df6_.head(1)
# Out:
#    Unnamed: 0          CREATE_DATE  IS_MAINTENANCE  VEHICLE_ID  \
# 0           0  2010-12-29 10:50:56               1     5000001
#
#    TOTAL_AMOUNT_TL
# 0          192.000

# %%
df6_.columns= df6_.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')

# %%
df6_.head(1)
# Out:
#    unnamed:_0          create_date  is_maintenance  vehicle_id  \
# 0           0  2010-12-29 10:50:56               1     5000001
#
#    total_amount_tl
# 0          192.000

# %%
df6_.drop("unnamed:_0", axis=1, inplace=True)

# %%
df6_.head(1)
# Out:
#            create_date  is_maintenance  vehicle_id  total_amount_tl
# 0  2010-12-29 10:50:56               1     5000001          192.000

# %%
df6_.groupby("vehicle_id")["total_amount_tl"].mean()
# Out:
# vehicle_id
# 5000001    644.000
# 5000003    943.000
# 5000007   1689.000
# 5000008        NaN
# 5000013    154.500
#             ...
# 5344976   1180.000
# 5344981      0.000
# 5344999   3258.000
# 5345037      1.000
# 5345048    604.000
# Name: total_amount_tl, Length: 225447, dtype: float64

# %%
aa = pd.DataFrame(df6_.groupby("vehicle_id")["total_amount_tl"].sum())

# %%
aa.reset_index(inplace=True)

# %%
aa.head(1)
# Out:
#    vehicle_id  total_amount_tl
# 0     5000001         3220.000

# %%
aa.columns
# Out:
# Index(['vehicle_id', 'total_amount_tl'], dtype='object')

# %%
len(aa)
# Out:
# 225447

# %%
bb = df6_[["vehicle_id", "is_maintenance"]]

# %%
bb["bakım"]=bb["is_maintenance"]

# %%
bb.head(1)
# Out:
#    vehicle_id  is_maintenance  bakım
# 0     5000001               1      1

# %%
bb.rename({"is_maintenance":"servis"}, axis=1, inplace=True)

# %%
bb.head(1)
# Out:
#    vehicle_id  servis  bakım
# 0     5000001       1      1

# %%
bb["bakım"] = bb["bakım"].replace(0,2)

# %%
bb["bakım"] = bb["bakım"].replace(1,0)

# %%
bb["bakım"] = bb["bakım"].replace(2,1)

# %%
bb.head(5)
# Out:
#    vehicle_id  servis  bakım
# 0     5000001       1      0
# 1     5000001       1      0
# 2     5000001       1      0
# 3     5000001       0      1
# 4     5000001       1      0

# %%
cc = pd.DataFrame(bb.groupby("vehicle_id")["servis"].sum())

# %%
cc.reset_index(inplace=True)

# %%
cc.head(1)
# Out:
#    vehicle_id  servis
# 0     5000001       4

# %%
dd = pd.DataFrame(bb.groupby("vehicle_id")["bakım"].sum())

# %%
dd.reset_index(inplace=True)

# %%
dd.head(1)
# Out:
#    vehicle_id  bakım
# 0     5000001      1

# %%
df_ = df_.merge(df2_, on = "base_customer_id", how='left')

# %%
df6_yeni = aa.merge(cc, on = "vehicle_id", how = "left")

# %%
df6_yeni = df6_yeni.merge(dd, on = "vehicle_id", how = "left")

# %%
df6_yeni.head()
# Out:
#    vehicle_id  total_amount_tl  servis  bakım
# 0     5000001         3220.000       4      1
# 1     5000003          943.000       0      1
# 2     5000007         1689.000       0      1
# 3     5000008            0.000       0      1
# 4     5000013          618.000       0      4

# %%
df6_yeni.shape
# Out:
# (225447, 4)

# %%
df6_yeni["servis"].value_counts()
# Out:
# 1     61130
# 0     55859
# 2     37061
# 3     25005
# 4     15960
# 5     10649
# 6      7004
# 7      4653
# 8      2809
# 9      1897
# 10     1257
# 11      839
# 12      450
# 13      275
# 14      178
# 15      120
# 16       90
# 17       65
# 18       46
# 19       29
# 20       22
# 21       15
# 22        7
# 25        4
# 23        3
# 24        3
# 28        3
# 29        3
# 32        2
# 33        2
# 26        2
# 31        2
# 30        1
# 36        1
# 37        1
# Name: servis, dtype: int64

# %%
df6_yeni["bakım"].value_counts()
# Out:
# 1     71126
# 0     43420
# 2     37748
# 3     23069
# 4     14985
# 5      9663
# 6      6775
# 7      4873
# 8      3352
# 9      2497
# 10     1832
# 11     1322
# 12     1078
# 13      751
# 14      565
# 15      474
# 16      367
# 17      294
# 18      234
# 19      185
# 20      134
# 21      118
# 22      103
# 23       85
# 24       56
# 25       41
# 28       37
# 27       36
# 26       34
# 29       25
# 30       25
# 32       23
# 34       17
# 33       14
# 35       14
# 31       10
# 42        8
# 39        7
# 36        7
# 37        4
# 38        4
# 51        4
# 50        4
# 47        4
# 45        3
# 46        3
# 43        3
# 41        3
# 40        2
# 52        2
# 44        1
# 48        1
# 54        1
# 55        1
# 57        1
# 63        1
# 64        1
# Name: bakım, dtype: int64
