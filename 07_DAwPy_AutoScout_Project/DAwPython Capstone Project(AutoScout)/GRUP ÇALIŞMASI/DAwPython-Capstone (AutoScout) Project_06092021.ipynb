# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# The project consists of 3 parts:
# * First part is related with 'data cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, Dropping useless columns.
# * Second part is related with 'filling data'. It deals with Missing Values. Categorical to numeric transformation is done.
# * Third part is related with 'handling outliers of data' via Visualisation libraries. Some insights are extracted.

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %%
import pandas as pd

# %%
df = pd.read_json("scout_car.json",lines=True,orient='columns')
df.head(1)
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                              short_description body_type  price  \
# 0  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
#
#               vat         km registration         prev_owner  kW  ...  \
# 0  VAT deductible  56,013 km      01/2016  2 previous owners NaN  ...
#
#                                          description Emission Label Gears  \
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahr...            NaN   NaN
#
#   Country version Electricity consumption Last Service Date Other Fuel Types  \
# 0             NaN                     NaN               NaN              NaN
#
#   Availability Last Timing Belt Service Date Available from
# 0          NaN                           NaN            NaN
#
# [1 rows x 54 columns]

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
df.tail(1)
# Out:
#                                                      url      make_model  \
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                  short_description body_type  price  \
# 15918  INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                   vat    km registration        prev_owner  kW  ...  \
# 15918  VAT deductible  - km      01/2019  1 previous owner NaN  ...
#
#                                              description   Emission Label  \
# 15918  [\n, Sicherheit Airbags:,  , Seitenairbag,  , ...  [\n4 (Green)\n]
#
#       Gears Country version Electricity consumption Last Service Date  \
# 15918   NaN   [\nGermany\n]                     NaN               NaN
#
#       Other Fuel Types Availability Last Timing Belt Service Date  \
# 15918              NaN          NaN                           NaN
#
#       Available from
# 15918            NaN
#
# [1 rows x 54 columns]

# %%
df.sample(5)
# Out:
#                                                      url     make_model  \
# 11617  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
# 3884   https://www.autoscout24.com//offers/audi-a3-30...        Audi A3
# 1585   https://www.autoscout24.com//offers/audi-a1-sp...        Audi A1
# 9380   https://www.autoscout24.com//offers/opel-corsa...     Opel Corsa
# 13371  https://www.autoscout24.com//offers/renault-cl...   Renault Clio
#
#                                        short_description      body_type  \
# 11617                  A Country Tourer 2.0 CDTI ecoFlex  Station wagon
# 3884       30 TFSI Sportback Basis 116PS,/4 Jahr Garanti  Station wagon
# 1585   Sportback S line 1.4 TFSI (150 PS) S tronic XENON        Compact
# 9380                                         1.4 Edition         Sedans
# 13371   Sporter dCi 8V 90CV EDC Start&Stop Energy Intens  Station wagon
#
#        price               vat         km registration        prev_owner  kW  \
# ...

# %%
df.shape
# Out:
# (15919, 54)

# %%
df.size
# Out:
# 859626

# %%
df.describe()
# Out:
#               price   kW
# count  15919.000000  0.0
# mean   18019.896727  NaN
# std     7386.169409  NaN
# min       13.000000  NaN
# 25%    12850.000000  NaN
# 50%    16900.000000  NaN
# 75%    21900.000000  NaN
# max    74600.000000  NaN

# %%
df.describe(include = object).T
# Out:
#                                count unique  \
# url                            15919  15919
# make_model                     15919      9
# short_description              15873  10001
# body_type                      15859      9
# vat                            11406      2
# km                             15919   6690
# registration                   15919     48
# prev_owner                      9091      4
# hp                             15919     81
# Type                           15917    169
# Previous Owners                 9279    102
# Next Inspection                 3535   1399
# Inspection new                  3932    202
# Warranty                       10499    515
# Full Service                    8215    122
# Non-smoking Vehicle             7177     94
# null                           15919      1
# Make                           15919      3
# Model                          15919      9
# Offer Number                   12744  11440
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
# ...

# %%
dtypes = pd.DataFrame(df.dtypes, columns = ['dtypes'])
dtypes
# Out:
#                                 dtypes
# url                             object
# make_model                      object
# short_description               object
# body_type                       object
# price                            int64
# vat                             object
# km                              object
# registration                    object
# prev_owner                      object
# kW                             float64
# hp                              object
# Type                            object
# Previous Owners                 object
# Next Inspection                 object
# Inspection new                  object
# Warranty                        object
# Full Service                    object
# Non-smoking Vehicle             object
# null                            object
# Make                            object
# Model                           object
# Offer Number                    object
# First Registration              object
# ...

# %%
notnull = pd.DataFrame(df.notnull().sum(), columns = ['notnull'])
notnull
# Out:
#                                notnull
# url                              15919
# make_model                       15919
# short_description                15873
# body_type                        15859
# price                            15919
# vat                              11406
# km                               15919
# registration                     15919
# prev_owner                        9091
# kW                                   0
# hp                               15919
# Type                             15917
# Previous Owners                   9279
# Next Inspection                   3535
# Inspection new                    3932
# Warranty                         10499
# Full Service                      8215
# Non-smoking Vehicle               7177
# null                             15919
# Make                             15919
# Model                            15919
# Offer Number                     12744
# First Registration               14322
# ...

# %%
isnull = pd.DataFrame(df.isnull().sum(), columns = ['isnull'])
isnull
# Out:
#                                isnull
# url                                 0
# make_model                          0
# short_description                  46
# body_type                          60
# price                               0
# vat                              4513
# km                                  0
# registration                        0
# prev_owner                       6828
# kW                              15919
# hp                                  0
# Type                                2
# Previous Owners                  6640
# Next Inspection                 12384
# Inspection new                  11987
# Warranty                         5420
# Full Service                     7704
# Non-smoking Vehicle              8742
# null                                0
# Make                                0
# Model                               0
# Offer Number                     3175
# First Registration               1597
# Body Color                        597
# ...

# %%
for column in df.columns:
    percentage = df[column].isnull().mean()
    print(f'{column}:{round(percentage*100, 2)}%')
# Out:
# url:0.0%
# make_model:0.0%
# short_description:0.29%
# body_type:0.38%
# price:0.0%
# vat:28.35%
# km:0.0%
# registration:0.0%
# prev_owner:42.89%
# kW:100.0%
# hp:0.0%
# Type:0.01%
# Previous Owners:41.71%
# Next Inspection:77.79%
# Inspection new:75.3%
# Warranty:34.05%
# Full Service:48.39%
# Non-smoking Vehicle:54.92%
# null:0.0%
# Make:0.0%
# Model:0.0%
# Offer Number:19.94%
# First Registration:10.03%
# Body Color:3.75%
# Paint Type:36.26%
# Body Color Original:23.61%
# Upholstery:23.37%
# Body:0.38%
# Nr. of Doors:1.33%
# Nr. of Seats:6.14%
# Model Code:68.73%
# Gearing Type:0.0%
# Displacement:3.12%
# Cylinders:35.68%
# Weight:43.81%
# Drive chain:43.08%
# Fuel:0.0%
# Consumption:11.97%
# CO2 Emission:11.36%
# Emission Class:18.98%
#
# Comfort & Convenience
# :5.78%
#
# Entertainment & Media
# :8.63%
#
# Extras
# :18.61%
#
# Safety & Security
# :6.17%
# description:0.0%
# Emission Label:74.97%
# Gears:29.6%
# Country version:52.35%
# Electricity consumption:99.14%
# ...

# %%
df_summary = pd.concat([dtypes, notnull, isnull], axis = 1).reset_index().rename({'index':'Columns'},axis = 1)
df_summary
# Out:
#                           Columns   dtypes  notnull  isnull
# 0                             url   object    15919       0
# 1                      make_model   object    15919       0
# 2               short_description   object    15873      46
# 3                       body_type   object    15859      60
# 4                           price    int64    15919       0
# 5                             vat   object    11406    4513
# 6                              km   object    15919       0
# 7                    registration   object    15919       0
# 8                      prev_owner   object     9091    6828
# 9                              kW  float64        0   15919
# 10                             hp   object    15919       0
# 11                           Type   object    15917       2
# 12                Previous Owners   object     9279    6640
# 13                Next Inspection   object     3535   12384
# 14                 Inspection new   object     3932   11987
# ...

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %% [markdown]
# ### COLUMN-1 url
#
# Tüm satırlar dolu. DROP edip edilmeyeceğine daha sonra karar verilecek.

# %%
df.url
# Out:
# 0        https://www.autoscout24.com//offers/audi-a1-sp...
# 1        https://www.autoscout24.com//offers/audi-a1-1-...
# 2        https://www.autoscout24.com//offers/audi-a1-sp...
# 3        https://www.autoscout24.com//offers/audi-a1-1-...
# 4        https://www.autoscout24.com//offers/audi-a1-sp...
#                                ...
# 15914    https://www.autoscout24.com//offers/renault-es...
# 15915    https://www.autoscout24.com//offers/renault-es...
# 15916    https://www.autoscout24.com//offers/renault-es...
# 15917    https://www.autoscout24.com//offers/renault-es...
# 15918    https://www.autoscout24.com//offers/renault-es...
# Name: url, Length: 15919, dtype: object

# %% [markdown]
# ### COLUMN-2 make_model
#
# Temiz sütun. Kullanılabilir. 19 (Make) ve 20 (Model) sütunlarla beraber değerlendirilecek

# %%
df.make_model
# Out:
# 0               Audi A1
# 1               Audi A1
# 2               Audi A1
# 3               Audi A1
# 4               Audi A1
#               ...
# 15914    Renault Espace
# 15915    Renault Espace
# 15916    Renault Espace
# 15917    Renault Espace
# 15918    Renault Espace
# Name: make_model, Length: 15919, dtype: object

# %%
df.make_model.unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %% [markdown]
# ### COLUMN-3 short_description

# %%
df.short_description
# Out:
# 0              Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1                                           1.8 TFSI sport
# 2        Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3                                  1.4 TDi Design S tronic
# 4        Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
#                                ...
# 15914                Blue dCi 200CV EDC Executive 4Control
# 15915                  TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916    Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917    Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918          INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
# Name: short_description, Length: 15919, dtype: object

# %% [markdown]
# ### COLUMN-4 body_type

# %%
df.body_type.value_counts()
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %% [markdown]
# ### COLUMN-5 price

# %%
df.price.nunique()
# Out:
# 2956

# %% [markdown]
# ### COLUMN-6 vat

# %%
df.vat.value_counts()
# Out:
# VAT deductible      10980
# Price negotiable      426
# Name: vat, dtype: int64

# %% [markdown]
# ### COLUMN-7 km

# %%
df.km.value_counts()
# Out:
# 10 km         1045
# - km          1024
# 1 km           367
# 5 km           170
# 50 km          148
#               ...
# 92,470 km        1
# 15,243 km        1
# 176,476 km       1
# 87,750 km        1
# 37,649 km        1
# Name: km, Length: 6690, dtype: int64

# %% [markdown]
# ### COLUMN-8 registration

# %%
df.registration.value_counts() # 22 sütunla karşılaştırmalı kullanımına karar verilecek
# Out:
# -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 04/2018     541
# 01/2019     541
# 02/2018     539
# 03/2016     536
# 06/2018     532
# 04/2016     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2018     141
# 09/2016     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 08/2019       1
# 11/2019       1
# 12/2019       1
# Name: registration, dtype: int64

# %% [markdown]
# ### COLUMN-9 prev_owner

# %%
df.prev_owner.value_counts()
# Out:
# 1 previous owner     8294
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
df[["prev_owner", "Previous Owners"]]
# Out:
#               prev_owner                                    Previous Owners
# 0      2 previous owners                                              \n2\n
# 1                   None                                                NaN
# 2       1 previous owner                                              \n1\n
# 3       1 previous owner                                              \n1\n
# 4       1 previous owner                                              \n1\n
# ...                  ...                                                ...
# 15914               None                                                NaN
# 15915   1 previous owner  [\n1\n, \n, 7.4 l/100 km (comb), \n, 9.2 l/100...
# 15916   1 previous owner                   [\n1\n, \n139 g CO2/km (comb)\n]
# 15917               None                                                NaN
# 15918   1 previous owner                                              \n1\n
#
# [15919 rows x 2 columns]

# %%
df["Previous Owners"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# \n1\n                               8101
# \n2\n                                766
# \n0\n                                163
# \n3\n                                 17
# [\n1\n, \n168 g CO2/km (comb)\n]      13
#                                     ...
# [\n1\n, \n137 g CO2/km (comb)\n]       1
# [\n2\n, \n127 g CO2/km (comb)\n]       1
# [\n1\n, \n159 g CO2/km (comb)\n]       1
# [\n0\n, \n117 g CO2/km (comb)\n]       1
# ...

# %% [markdown]
# ### COLUMN-10 kW

# %%
# DROP edilecek

# %% [markdown]
# ### COLUMN-11 hp

# %%
df.hp.value_counts().index
# Out:
# Index(['85 kW', '66 kW', '81 kW', '100 kW', '110 kW', '70 kW', '125 kW',
#        '51 kW', '55 kW', '118 kW', '92 kW', '121 kW', '147 kW', '77 kW',
#        '56 kW', '54 kW', '103 kW', '87 kW', '165 kW', '88 kW', '60 kW',
#        '162 kW', '- kW', '74 kW', '96 kW', '71 kW', '101 kW', '67 kW',
#        '154 kW', '122 kW', '119 kW', '164 kW', '135 kW', '82 kW', '52 kW',
#        '1 kW', '78 kW', '294 kW', '146 kW', '141 kW', '57 kW', '104 kW',
#        '120 kW', '191 kW', '112 kW', '117 kW', '155 kW', '184 kW', '76 kW',
#        '90 kW', '65 kW', '80 kW', '93 kW', '149 kW', '98 kW', '168 kW',
#        '53 kW', '150 kW', '167 kW', '40 kW', '89 kW', '86 kW', '140 kW',
#        '270 kW', '127 kW', '228 kW', '63 kW', '143 kW', '75 kW', '163 kW',
#        '133 kW', '44 kW', '123 kW', '84 kW', '115 kW', '132 kW', '239 kW',
#        '9 kW', '195 kW', '137 kW', '4 kW'],
#       dtype='object')

# %% [markdown]
# ### COLUMN-12 Type

# %%
df.Type.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [, Used, , Diesel (Particulate Filter)]                                                                                                       3475
# [, Used, , Diesel]                                                                                                                            2516
# ...

# %% [markdown]
# ### COLUMN-13 Previous Owners

# %%
# 9 column ile beraber değerlendirilecek

# %% [markdown]
# ### COLUMN-14 Next Inspection

# %%
df["Next Inspection"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# \n04/2022\n                               62
# \n03/2021\n                               38
# \n03/2022\n                               36
# \n06/2021\n                               34
# \n01/2022\n                               32
#                                           ..
# [\n08/2019\n, \n104 g CO2/km (comb)\n]     1
# [\n12/2019\n, \n112 g CO2/km (comb)\n]     1
# [\n01/2020\n, \n102 g CO2/km (comb)\n]     1
# ...

# %% [markdown]
# ### COLUMN-15 Inspection new

# %%
df["Inspection new"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nYes\n, \nEuro 6\n]                                                                          523
# \nYes\n                                                                                        362
# [\nYes\n, \n102 g CO2/km (comb)\n]                                                             174
# [\nYes\n, \n4 (Green)\n]                                                                       166
# ...

# %% [markdown]
# ### COLUMN-16 Warranty

# %%
df[["Warranty","Emission Label", "CO2 Emission", "Emission Class"]].sample(20)
# Out:
#                                        Warranty   Emission Label  \
# 5993                                        NaN              NaN
# 7115          [\n, \n, \n135 g CO2/km (comb)\n]  [\n4 (Green)\n]
# 4174                      [\n, \n, \nEuro 6d\n]              NaN
# 15765               [\n60 months\n, \nEuro 6\n]              NaN
# 1228          [\n, \n, \n120 g CO2/km (comb)\n]              NaN
# 10185  [\n72 months\n, \n129 g CO2/km (comb)\n]              NaN
# 15858              [\n24 months\n, \nEuro 6d\n]              NaN
# 5104                                        NaN              NaN
# 5209                                        NaN  [\n4 (Green)\n]
# 5349                                        NaN  [\n4 (Green)\n]
# 9770                                   [\n, \n]  [\n4 (Green)\n]
# 11477                   [\n, \n, \n4 (Green)\n]              NaN
# 14956                             \n12 months\n              NaN
# ...

# %% [markdown]
# ### COLUMN-17 Full Service

# %%
df["Full Service"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, \n, \n4 (Green)\n]                                                                       2235
# [\n, \n, \nEuro 6\n]                                                                          2097
# [\n, \n]                                                                                      1702
# [\n, \n, \nEuro 6d-TEMP\n]                                                                     399
# ...

# %% [markdown]
# ### COLUMN-18 Non-smoking Vehicle

# %%
df["Non-smoking Vehicle"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, \n]                                                                                      3647
# [\n, \n, \n4 (Green)\n]                                                                       1240
# [\n, \n, \nEuro 6\n]                                                                          1127
# [\n, \n, \nEuro 6d-TEMP\n]                                                                     345
# ...

# %% [markdown]
# ### COLUMN-19 null

# %%
df["null"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []    15919
# Name: null, dtype: int64

# %% [markdown]
# ### COLUMN-20 Make

# %%
df[["make_model", "Make", "Model"]].sample(50)
# Out:
#            make_model         Make               Model
# 5768       Opel Astra     \nOpel\n     [\n, Astra, \n]
# 12317   Opel Insignia     \nOpel\n  [\n, Insignia, \n]
# 11840   Opel Insignia     \nOpel\n  [\n, Insignia, \n]
# 12841   Opel Insignia     \nOpel\n  [\n, Insignia, \n]
# 3095          Audi A3     \nAudi\n        [\n, A3, \n]
# 5053          Audi A3     \nAudi\n        [\n, A3, \n]
# 3457          Audi A3     \nAudi\n        [\n, A3, \n]
# 10814   Opel Insignia     \nOpel\n  [\n, Insignia, \n]
# 5862       Opel Astra     \nOpel\n     [\n, Astra, \n]
# 10728   Opel Insignia     \nOpel\n  [\n, Insignia, \n]
# 7337       Opel Astra     \nOpel\n     [\n, Astra, \n]
# 7955       Opel Astra     \nOpel\n     [\n, Astra, \n]
# 5999       Opel Astra     \nOpel\n     [\n, Astra, \n]
# 12417   Opel Insignia     \nOpel\n  [\n, Insignia, \n]
# 11201   Opel Insignia     \nOpel\n  [\n, Insignia, \n]
# 11784   Opel Insignia     \nOpel\n  [\n, Insignia, \n]
# ...

# %% [markdown]
# ### COLUMN-21 Model

# %%
# 20. sütun ile beraber düşürülecek

# %% [markdown]
# ### COLUMN-22 Offer Number

# %%
df["Offer Number"].value_counts().sample(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n331452\n]               1
# [\n455313\n]               1
# [\nAI,142040\n]            1
# [\n220751\n]               1
# [\nB11232-Q2\n]            1
# [\n76313\n]                1
# [\n4944025\n]              4
# [\nH1028991\n]             1
# [\n246086432\n]            1
# [\n519027\n]               1
# [\n71283\n]                1
# [\nG564\n]                 1
# [\n2000713/19\n]           1
# ...

# %% [markdown]
# ### COLUMN-23 First Registration

# %%
df["First Registration"] # 8 sütunla karşılaştırmalı kullanımına karar verilecek
# Out:
# 0        [\n, 2016, \n]
# 1        [\n, 2017, \n]
# 2        [\n, 2016, \n]
# 3        [\n, 2016, \n]
# 4        [\n, 2016, \n]
#               ...
# 15914               NaN
# 15915    [\n, 2019, \n]
# 15916    [\n, 2019, \n]
# 15917    [\n, 2019, \n]
# 15918    [\n, 2019, \n]
# Name: First Registration, Length: 15919, dtype: object

# %% [markdown]
# ### COLUMN-24 Body Color

# %%
df[["Body Color", "Body Color Original", "Paint Type"]].sample(50)
# Out:
#              Body Color                   Body Color Original      Paint Type
# 13917   [\n, Black, \n]                            [\nNero\n]  [\nMetallic\n]
# 2251    [\n, White, \n]                  [\nBianco Cortina\n]             NaN
# 12280    [\n, Blue, \n]                    [\nDiamant Blau\n]  [\nMetallic\n]
# 15338  [\n, Silver, \n]                 [\nSilber Metallic\n]  [\nMetallic\n]
# 5005    [\n, Black, \n]       [\nBrilliant Schwarz/Schwarz\n]             NaN
# 6366     [\n, Grey, \n]                                   NaN  [\nMetallic\n]
# 1347    [\n, White, \n]                                   NaN  [\nMetallic\n]
# 9974      [\n, Red, \n]             [\nLava Rot (Brillant)\n]             NaN
# 11259  [\n, Silver, \n]                     [\nArgonsilber\n]  [\nMetallic\n]
# 9463     [\n, Grey, \n]                    [\nGrigio scuro\n]  [\nMetallic\n]
# 11362  [\n, Silver, \n]            [\nArgonsilber Metallic\n]  [\nMetallic\n]
# ...

# %% [markdown]
# ### COLUMN-25 Paint Type

# %%
df["Paint Type"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nMetallic\n]       9794
# [\nUni/basic\n]       347
# [\nPerl effect\n]       6
# Name: Paint Type, dtype: int64

# %% [markdown]
# ### COLUMN-26 Body Color Original

# %%
df["Body Color Original"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nOnyx Schwarz\n]              338
# [\nBianco\n]                    282
# [\nMythosschwarz Metallic\n]    238
# [\nBrillantschwarz\n]           216
# [\nGris\n]                      204
#                                ...
# [\nBleu Celeste\n]                1
# [\nBlu cosmo metallizzato\n]      1
# [\nBlac Ivoire D16\n]             1
# [\nkarbonschwarz met\n]           1
# [\nSATIN STEEL\n]                 1
# ...

# %% [markdown]
# ### COLUMN-27 Upholstery

# %%
df["Upholstery"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nCloth, Black\n]           5821
# [\nPart leather, Black\n]    1121
# [\nCloth\n]                  1005
# [\nCloth, Grey\n]             891
# [\nCloth, Other\n]            639
# [\nFull leather, Black\n]     575
# [\nBlack\n]                   491
# [\nGrey\n]                    273
# [\nOther, Other\n]            182
# [\nPart leather\n]            140
# [\nFull leather\n]            139
# ...

# %% [markdown]
# ### COLUMN-28 Body

# %%
df.Body.value_counts() # drop edilecek
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Sedans, \n]           7903
# [\n, Station wagon, \n]    3553
# [\n, Compact, \n]          3153
# [\n, Van, \n]               783
# [\n, Other, \n]             290
# [\n, Transporter, \n]        88
# [\n, Off-Road, \n]           56
# [\n, Coupe, \n]              25
# [\n, Convertible, \n]         8
# Name: Body, dtype: int64

# %% [markdown]
# ### COLUMN-29 Nr. of Doors

# %%
df["Nr. of Doors"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n5\n]    11575
# [\n4\n]     3079
# [\n3\n]      832
# [\n2\n]      219
# [\n7\n]        1
# [\n1\n]        1
# Name: Nr. of Doors, dtype: int64

# %% [markdown]
# ### COLUMN-30 Nr. of Seats

# %%
df["Nr. of Seats"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n5\n]    13336
# [\n4\n]     1125
# [\n7\n]      362
# [\n2\n]      116
# [\n6\n]        2
# [\n3\n]        1
# Name: Nr. of Seats, dtype: int64

# %% [markdown]
# ### COLUMN-31 Model Code

# %%
df["Model Code"].value_counts().sample(25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n0035/BAG\n]      1
# [\n0035/BEM\n]      1
# [\n3333/BAD\n]      9
# [\n0588/AVQ\n]      1
# [\n0035/BAQ\n]      7
# [\n0588/AWJ\n]     82
# [\n1844/AHR\n]      1
# [\n0588/BCW\n]     31
# [\n0588/AZZ\n]      1
# [\n0588/BAF\n]      7
# [\n0588/AZX\n]     21
# [\n1844/AFE\n]      7
# [\n0588/BDB\n]    206
# [\n0035/BGY\n]      1
# [\n0035/BEO\n]      9
# [\n1844/ADL\n]      2
# [\n0035/BFM\n]     84
# ...

# %% [markdown]
# ### COLUMN-32 Gearing Type

# %%
df[["Gearing Type", "Gears"]].sample(50)  # 46. sütun ile beraber değerlendir
# Out:
#               Gearing Type    Gears
# 9118      [\n, Manual, \n]  [\n6\n]
# 11097     [\n, Manual, \n]  [\n6\n]
# 4147      [\n, Manual, \n]  [\n6\n]
# 14467  [\n, Automatic, \n]  [\n6\n]
# 1994   [\n, Automatic, \n]      NaN
# 6784      [\n, Manual, \n]  [\n5\n]
# 15144  [\n, Automatic, \n]  [\n6\n]
# 1978   [\n, Automatic, \n]  [\n7\n]
# 6236      [\n, Manual, \n]  [\n6\n]
# 14090  [\n, Automatic, \n]      NaN
# 2937   [\n, Automatic, \n]      NaN
# 12465  [\n, Automatic, \n]      NaN
# 10951     [\n, Manual, \n]  [\n6\n]
# 11260     [\n, Manual, \n]  [\n6\n]
# 2422      [\n, Manual, \n]  [\n5\n]
# 6597   [\n, Automatic, \n]  [\n6\n]
# 3075      [\n, Manual, \n]      NaN
# 12538  [\n, Automatic, \n]  [\n8\n]
# 2490      [\n, Manual, \n]      NaN
# 12404  [\n, Automatic, \n]  [\n6\n]
# 5466      [\n, Manual, \n]      NaN
# 5514      [\n, Manual, \n]      NaN
# 11212     [\n, Manual, \n]  [\n6\n]
# 1335      [\n, Manual, \n]  [\n5\n]
# 15329     [\n, Manual, \n]  [\n6\n]
# ...

# %% [markdown]
# ### COLUMN-33 Displacement

# %%
df["Displacement"]
# Out:
# 0        [\n1,422 cc\n]
# 1        [\n1,798 cc\n]
# 2        [\n1,598 cc\n]
# 3        [\n1,422 cc\n]
# 4        [\n1,422 cc\n]
#               ...
# 15914    [\n1,997 cc\n]
# 15915    [\n1,798 cc\n]
# 15916    [\n1,997 cc\n]
# 15917    [\n1,997 cc\n]
# 15918    [\n1,798 cc\n]
# Name: Displacement, Length: 15919, dtype: object

# %% [markdown]
# ### COLUMN-34 Cylinders

# %%
df["Cylinders"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n4\n]    8105
# [\n3\n]    2104
# [\n5\n]      22
# [\n6\n]       3
# [\n2\n]       2
# [\n8\n]       2
# [\n1\n]       1
# Name: Cylinders, dtype: int64

# %% [markdown]
# ### COLUMN-35 Weight

# %%
df["Weight"]
# Out:
# 0        [\n1,220 kg\n]
# 1        [\n1,255 kg\n]
# 2                   NaN
# 3        [\n1,195 kg\n]
# 4                   NaN
#               ...
# 15914    [\n1,758 kg\n]
# 15915    [\n1,708 kg\n]
# 15916               NaN
# 15917    [\n1,758 kg\n]
# 15918    [\n1,685 kg\n]
# Name: Weight, Length: 15919, dtype: object

# %% [markdown]
# ### COLUMN-36 Drive chain

# %%
df["Drive chain"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nfront\n]    8886
# [\n4WD\n]       171
# [\nrear\n]        4
# Name: Drive chain, dtype: int64

# %% [markdown]
# ### COLUMN-37 Fuel

# %%
df[["Fuel", "Type"]]
# Out:
#                                                     Fuel  \
# 0                  [\n, Diesel (Particulate Filter), \n]
# 1                                     [\n, Gasoline, \n]
# 2                  [\n, Diesel (Particulate Filter), \n]
# 3                  [\n, Diesel (Particulate Filter), \n]
# 4                  [\n, Diesel (Particulate Filter), \n]
# ...                                                  ...
# 15914              [\n, Diesel (Particulate Filter), \n]
# 15915  [\n, Super 95 / Super Plus 98 (Particulate Fil...
# 15916                                   [\n, Diesel, \n]
# 15917                                   [\n, Diesel, \n]
# 15918                                 [\n, Super 95, \n]
#
#                                                     Type
# 0                [, Used, , Diesel (Particulate Filter)]
# 1                                   [, Used, , Gasoline]
# 2                [, Used, , Diesel (Particulate Filter)]
# ...

# %% [markdown]
# ### COLUMN-38 Consumption

# %%
df["Consumption"]
# Out:
# 0        [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1        [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2        [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3        [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4        [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
#                                ...
# 15914    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915    [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918    [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
# Name: Consumption, Length: 15919, dtype: object

# %% [markdown]
# ### COLUMN-39 CO2 Emission

# %%
df[["CO2 Emission", "Emission Class", "Emission Label"]].sample(20)
# Out:
#                     CO2 Emission      Emission Class        Emission Label
# 108     [\n92 g CO2/km (comb)\n]        [\nEuro 6\n]                   NaN
# 12527  [\n186 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]                   NaN
# 8516                [[], [], []]                 NaN                   NaN
# 5241   [\n114 g CO2/km (comb)\n]                 NaN  [\n1 (No sticker)\n]
# 5128   [\n110 g CO2/km (comb)\n]        [\nEuro 6\n]       [\n4 (Green)\n]
# 11153   [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]                   NaN
# 4088   [\n107 g CO2/km (comb)\n]        [\nEuro 6\n]                   NaN
# 12643  [\n147 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]                   NaN
# 12139  [\n139 g CO2/km (comb)\n]        [\nEuro 6\n]       [\n4 (Green)\n]
# 1515    [\n97 g CO2/km (comb)\n]        [\nEuro 6\n]                   NaN
# 2216   [\n106 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]                   NaN
# ...

# %% [markdown]
# ### COLUMN-40 Emission Class

# %%
# 39 sütunla beraber değerlendirilecek. 14-15-16-17-18 sütunlar benzer bilgi

# %% [markdown]
# ### COLUMN-41 \nComfort & Convenience\n

# %%
df["\nComfort & Convenience\n"][0]
# Out:
# ['Air conditioning',
#  'Armrest',
#  'Automatic climate control',
#  'Cruise control',
#  'Electrical side mirrors',
#  'Hill Holder',
#  'Leather steering wheel',
#  'Light sensor',
#  'Multi-function steering wheel',
#  'Navigation system',
#  'Park Distance Control',
#  'Parking assist system sensors rear',
#  'Power windows',
#  'Rain sensor',
#  'Seat heating',
#  'Start-stop system']

# %% [markdown]
# ### COLUMN-42 \nEntertainment & Media\n

# %%
df["\nEntertainment & Media\n"][0]
# Out:
# ['Bluetooth', 'Hands-free equipment', 'On-board computer', 'Radio']

# %% [markdown]
# ### COLUMN-43 \nExtras\n

# %%
df["\nExtras\n"][0]
# Out:
# ['Alloy wheels', 'Catalytic Converter', 'Voice Control']

# %% [markdown]
# ### COLUMN-44 \nSafety & Security\n

# %%
df["\nSafety & Security\n"][0]
# Out:
# ['ABS',
#  'Central door lock',
#  'Daytime running lights',
#  'Driver-side airbag',
#  'Electronic stability control',
#  'Fog lights',
#  'Immobilizer',
#  'Isofix',
#  'Passenger-side airbag',
#  'Power steering',
#  'Side airbag',
#  'Tire pressure monitoring system',
#  'Traction control',
#  'Xenon headlights']

# %%
### COLUMN-45 description

# %%
df["description"][0]
# Out:
# ['\n',
#  'Sicherheit:',
#  ' ',
#  'Deaktivierung für Beifahrer-Airbag',
#  ' ',
#  'ESC mit elektronischer Quersperre',
#  ' ',
#  'Tagfahrlicht',
#  ' ',
#  'Reifendruck-Kontrollanzeige',
#  ' ',
#  'Kopfairbag-System mit Seiten-Airbags vorn',
#  ' ',
#  'Sicherheitslenksäule',
#  'Assistenzsysteme:',
#  ' ',
#  'Berganfahrassistent',
#  'Komfort:',
#  ' ',
#  'Scheinwerferreinigung',
#  ' ',
#  'Xenon plus inklusive Scheinwerfer-Reinigungsanlage',
#  ' ',
#  'Scheinwerfer-Reinigungsanlage',
#  ' ',
#  'Einparkhilfe hinten',
#  ' ',
#  'Licht-/Regensensor',
#  ' ',
#  'Funkfernbedienung',
#  ' ',
#  'Elektrische Luftzusatzheizung',
#  'Interieur:',
#  ' ',
#  'Rücksitzanlage 2 + 1',
#  ' ',
#  'Multifunktions-Sportlederlenkrad im 3-Speichen-Design',
#  ' ',
#  'automatische Leuchtweitenregulierung',
#  ' ',
#  'Fahrerinformationssystem',
#  ' ',
#  'Staub- und Pollenfilter',
#  ' ',
#  'Kopfstützen hinten (3 Stück)',
#  ' ',
#  'Stoff Zeitgeist',
#  ' ',
# ...

# %%
### COLUMN-46 Emission Label

# %%
### COLUMN-47 Gears

# %%
df[["Gears", "Gearing Type"]] # 32. sütun ile beraber değerlendir
# Out:
#          Gears         Gearing Type
# 0          NaN  [\n, Automatic, \n]
# 1      [\n7\n]  [\n, Automatic, \n]
# 2          NaN  [\n, Automatic, \n]
# 3      [\n6\n]  [\n, Automatic, \n]
# 4          NaN  [\n, Automatic, \n]
# ...        ...                  ...
# 15914  [\n6\n]  [\n, Automatic, \n]
# 15915  [\n7\n]  [\n, Automatic, \n]
# 15916  [\n6\n]  [\n, Automatic, \n]
# 15917  [\n6\n]  [\n, Automatic, \n]
# 15918      NaN  [\n, Automatic, \n]
#
# [15919 rows x 2 columns]

# %%
### COLUMN-48 Country version

# %%
df[["Country version", "make_model"]].sample(25)
# Out:
#             Country version      make_model
# 15637           [\nItaly\n]  Renault Espace
# 6594          [\nGermany\n]      Opel Astra
# 3616      [\nNetherlands\n]         Audi A3
# 10663                   NaN   Opel Insignia
# 6561                    NaN      Opel Astra
# 3493          [\nGermany\n]         Audi A3
# 9729            [\nItaly\n]      Opel Corsa
# 2590                    NaN         Audi A1
# 7440                    NaN      Opel Astra
# 14866                   NaN    Renault Clio
# 12760     [\nNetherlands\n]   Opel Insignia
# 14576         [\nGermany\n]    Renault Clio
# 5797                    NaN      Opel Astra
# 10434         [\nGermany\n]      Opel Corsa
# 6098                    NaN      Opel Astra
# 10934           [\nItaly\n]   Opel Insignia
# 486       [\nNetherlands\n]         Audi A1
# 5927          [\nGermany\n]      Opel Astra
# 4441                    NaN         Audi A3
# 15558         [\nBelgium\n]  Renault Espace
# ...

# %%
### COLUMN-49 Electricity consumption

# %%
df["Electricity consumption"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n0 kWh/100 km (comb)\n]    137
# Name: Electricity consumption, dtype: int64

# %%
### COLUMN-50 Last Service Date

# %%
df["Last Service Date"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n02/2019\n, \nEuro 6\n]                 23
# [\n05/2019\n, \nEuro 6\n]                 16
# [\n01/2018\n, \n118 g CO2/km (comb)\n]    15
# [\n03/2019\n, \nEuro 6\n]                 15
# [\n06/2019\n, \nEuro 6\n]                 13
#                                           ..
# [\n06/2018\n, \n102 g CO2/km (comb)\n]     1
# [\n07/2018\n, \nEuro 6c\n]                 1
# [\n12/2018\n, \n5 (Blue)\n]                1
# ...

# %%
### COLUMN-51 Other Fuel Types

# %%
df["Other Fuel Types"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [[], [], []]    880
# Name: Other Fuel Types, dtype: int64

# %%
### COLUMN-52 Availability

# %%
df["Availability"].value_counts()
# Out:
# \nin 90 days from ordering\n     196
# \nin 120 days from ordering\n    182
# \nin 1 day from ordering\n        51
# \nin 3 days from ordering\n       35
# \nin 5 days from ordering\n       35
# \nin 14 days from ordering\n      24
# \nin 180 days from ordering\n     24
# \nin 7 days from ordering\n       20
# \nin 150 days from ordering\n     18
# \nin 2 days from ordering\n       16
# \nin 60 days from ordering\n      13
# \nin 42 days from ordering\n      10
# \nin 21 days from ordering\n       8
# \nin 4 days from ordering\n        2
# \nin 6 days from ordering\n        1
# Name: Availability, dtype: int64

# %%
### COLUMN-53 Last Timing Belt Service Date

# %%
df["Last Timing Belt Service Date"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n04/2016\n]                2
# [\n01/2019\n]                1
# [\n01/1970\n]                1
# [\n05/2019\n]                1
# [\n06/2017\n]                1
# [\n04/2019\n]                1
# [\n01/1900\n]                1
# [\n02/2018\n]                1
# [\n05/2018\n, \nEuro 6\n]    1
# [\n01/2018\n]                1
# [\n07/2018\n]                1
# [\n02/2019\n]                1
# [\n09/2018\n]                1
# ...

# %%
### COLUMN-54 Available from

# %%
a = df["Model Code"]=="[\n0035/BCB\n]"
a.value_counts()
# Out:
# False    15919
# Name: Model Code, dtype: int64

# %%
a = df["Model Code"]=="[\n0035/BCB\n]"
a.value_counts()
# Out:
# False    15919
# Name: Model Code, dtype: int64

# %%
a = df["Model Code"]=="[\n0035/BCB\n]"
a.value_counts()
# Out:
# False    15919
# Name: Model Code, dtype: int64

# %%
a = df["Model Code"]=="[\n0035/BCB\n]"
a.value_counts()
# Out:
# False    15919
# Name: Model Code, dtype: int64

# %%
df["Available from"].value_counts()
# Out:
# \n31/08/19\n    98
# \n30/07/19\n    25
# \n15/08/19\n    24
# \n16/09/19\n    14
# \n29/06/19\n    12
# \n01/07/19\n    11
# \n28/06/19\n    10
# \n19/08/19\n     7
# \n10/09/19\n     6
# \n10/11/19\n     5
# \n27/06/19\n     5
# \n26/06/19\n     5
# \n08/07/19\n     4
# \n15/07/19\n     3
# \n01/08/19\n     3
# \n25/10/19\n     3
# \n20/07/19\n     2
# \n30/06/19\n     2
# \n24/08/19\n     2
# \n05/07/19\n     2
# \n05/08/19\n     2
# \n16/07/19\n     2
# \n04/07/19\n     2
# \n27/07/19\n     1
# \n03/08/19\n     1
# \n06/12/19\n     1
# \n10/10/19\n     1
# \n01/09/19\n     1
# \n29/09/19\n     1
# \n10/12/19\n     1
# \n16/08/19\n     1
# \n02/07/19\n     1
# \n14/09/19\n     1
# \n18/08/19\n     1
# \n24/07/19\n     1
# \n19/07/19\n     1
# \n10/07/19\n     1
# \n11/08/19\n     1
# \n17/08/19\n     1
# \n31/10/19\n     1
# \n24/09/19\n     1
# \n29/07/19\n     1
# \n30/09/19\n     1
# \n03/12/19\n     1
# \n05/12/19\n     1
# \n18/07/19\n     1
# ...

# %%
df_summary
# Out:
#                           Columns   dtypes  notnull  isnull
# 0                             url   object    15919       0
# 1                      make_model   object    15919       0
# 2               short_description   object    15873      46
# 3                       body_type   object    15859      60
# 4                           price    int64    15919       0
# 5                             vat   object    11406    4513
# 6                              km   object    15919       0
# 7                    registration   object    15919       0
# 8                      prev_owner   object     9091    6828
# 9                              kW  float64        0   15919
# 10                             hp   object    15919       0
# 11                           Type   object    15917       2
# 12                Previous Owners   object     9279    6640
# 13                Next Inspection   object     3535   12384
# 14                 Inspection new   object     3932   11987
# ...

# %%
df.Model
# Out:
# 0            [\n, A1, \n]
# 1            [\n, A1, \n]
# 2            [\n, A1, \n]
# 3            [\n, A1, \n]
# 4            [\n, A1, \n]
#                ...
# 15914    [\n, Espace, \n]
# 15915    [\n, Espace, \n]
# 15916    [\n, Espace, \n]
# 15917    [\n, Espace, \n]
# 15918    [\n, Espace, \n]
# Name: Model, Length: 15919, dtype: object

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
df.body_type.describe(include=object)
# Out:
# count      15859
# unique         9
# top       Sedans
# freq        7903
# Name: body_type, dtype: object

# %%
df.body_type.unique()
# Out:
# array(['Sedans', 'Station wagon', 'Compact', 'Other', 'Coupe', 'Van',
#        'Off-Road', 'Convertible', None, 'Transporter'], dtype=object)

# %%
df.body_type.isnull().sum()
# Out:
# 60

# %% [markdown]
# ## Import Libraries and Data

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)
